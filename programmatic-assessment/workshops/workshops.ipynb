# %%
# Import all the things

import pandas as pd
# import seaborn as sns # not using this now
import matplotlib.pyplot as plt

from ipywidgets import interactive
from IPython.display import display
import ipywidgets as widgets
from ipywidgets import interact, widgets

import numpy as np

import collections

# %matplotlib inline

# %%
# Read in data

workshops  = pd.read_csv('workshops.csv')

# %%
workshops
# Out:
#                                           slug    tag_name  month  year  day  \
# 0                           2011-11-07-toronto         SWC     11  2011    7
# 1                             2012-01-18-stsci         SWC      1  2012   18
# 2                              2012-02-20-itcp         SWC      2  2012   20
# 3                           2012-02-23-toronto         SWC      2  2012   23
# 4                           2012-03-07-indiana         SWC      3  2012    7
# 5                             2012-03-26-mbari         SWC      3  2012   26
# 6                             2012-03-28-nersc         SWC      3  2012   28
# 7                           2012-04-02-chicago         SWC      4  2012    2
# 8                         2012-04-14-utahstate         SWC      4  2012   14
# 9                               2012-04-30-ucl         SWC      4  2012   30
# 10                    2012-05-07-michiganstate         SWC      5  2012    7
# 11                        2012-05-14-newcastle         SWC      5  2012   14
# 12                          2012-05-16-alberta         SWC      5  2012   16
# 13                              2012-05-22-ubc         SWC      5  2012   22
# 14                              2012-06-18-jhu         SWC      6  2012   18
# 15                            2012-06-28-inria         SWC      6  2012   28
# 16                              2012-07-09-mit         SWC      7  2012    9
# 17                              2012-07-10-ral         SWC      7  2012   10
# 18                         2012-07-12-waterloo         SWC      7  2012   12
# 19                          2012-07-16-halifax         SWC      7  2012   16
# 20                             2012-07-19-utsc         SWC      7  2012   19
# 21                       2012-08-26-ttt-online  TTT,online      8  2012   26
# 22                             2012-09-13-dafx         SWC      9  2012   13
# 23                             2012-09-17-oslo         SWC      9  2012   17
# 24                         2012-09-28-columbia         SWC      9  2012   28
# 25                           2012-10-08-purdue         SWC     10  2012    8
# 26                       2012-10-11-ttt-online  TTT,online     10  2012   11
# 27                              2012-10-17-lbl         SWC     10  2012   17
# 28                              2012-10-18-ubc         SWC     10  2012   18
# 29                              2012-10-20-ucb         SWC     10  2012   20
# ...                                        ...         ...    ...   ...  ...
# 1560                     2018-05-29-kingcounty         SWC      5  2018   29
# 1561                       2018-05-31-grenoble         SWC      5  2018   31
# 1562              2018-06-06-ResbazBris-Python         SWC      6  2018    6
# 1563                   2018-06-06-ResbazBris-R         SWC      6  2018    6
# 1564                           2018-06-11-BIDS         SWC      6  2018   11
# 1565                            2018-06-11-ttt  TTT,online      6  2018   11
# 1566                        2018-06-11-ttt-jax         TTT      6  2018   11
# 1567  2018-06-12-bru-datacarpentry-inbo-elixir          DC      6  2018   12
# 1568                            2018-06-12-ttt  TTT,online      6  2018   12
# 1569                           2018-06-12-wrds         SWC      6  2018   12
# 1570                       2018-06-18-ttt-usda         TTT      6  2018   18
# 1571                            2018-06-20-ttt  TTT,online      6  2018   20
# 1572                       2018-06-21-Oslo-ttt         TTT      6  2018   21
# 1573                           2018-06-27-LBNL          DC      6  2018   27
# 1574                            2018-06-27-ttt  TTT,online      6  2018   27
# 1582         NaN                                Stanford University
# 1583         NaN                                 Software Carpentry
# 1584         NaN              Lawrence Berkeley National Laboratory
# 1585         NaN                                 Software Carpentry
# 1586         NaN       The Centre for Research & Technology, Hellas
# 1587         NaN                                New York University
# 1588         NaN                            Old Dominion University
# 1589        18.0                                              VLSCI
#
#                          administrator_name country
# 0                            Compute Canada      CA
# 1                        Software Carpentry      US
# 2                                  Cyfronet      IT
# 3                            Compute Canada      CA
# 4                        Software Carpentry      US
# 5                        Software Carpentry      US
# 6                        Software Carpentry      US
# 7                        Software Carpentry      US
# 8                        Software Carpentry      US
# 9     SSI Software Sustainability Institute      GB
# 10                       Software Carpentry      US
# 11    SSI Software Sustainability Institute      GB
# 12                           Compute Canada      CA
# 13                           Compute Canada      CA
# 14                       Software Carpentry      US
# 15                                 Cyfronet      FR
# 16                       Software Carpentry      US
# 17    SSI Software Sustainability Institute      GB
# 18                           Compute Canada      CA
# 19                           Compute Canada      CA
# 20                           Compute Canada      CA
# 21                       Software Carpentry      W3
# 22    SSI Software Sustainability Institute      GB
# 23                                 Cyfronet      NO
# 24                       Software Carpentry      US
# 25                       Software Carpentry      US
# 26                       Software Carpentry      W3
# 27                       Software Carpentry      US
# 28                           Compute Canada      CA
# 29                       Software Carpentry      US
# ...                                     ...     ...
# 1560                     Software Carpentry     NaN
# 1561                         self-organized      FR
# 1562                    Griffith University      AU
# 1563                    Griffith University      AU
# 1564                     Software Carpentry      US
# 1565                     Software Carpentry      W3
# 1566                     Software Carpentry     NaN
# 1567                         self-organized      BE
# 1568                     Software Carpentry      W3
# 1569                         self-organized      AU
# 1570                     Software Carpentry     NaN
# 1571                     Software Carpentry      W3
# 1572                     Software Carpentry      NO
# 1573                         Data Carpentry     NaN
# 1574                     Software Carpentry      W3
# 1575                         Data Carpentry     NaN
# 1576                     Software Carpentry     NaN
# 1577                     Software Carpentry      US
# 1578                     Software Carpentry     NaN
# 1579                     Software Carpentry     NaN
# 1580                     Software Carpentry      W3
# 1581                     Software Carpentry      W3
# 1582                     Software Carpentry     NaN
# 1583                     Software Carpentry      W3
# 1584                         Data Carpentry     NaN
# 1585                     Software Carpentry      W3
# 1586                         self-organized      GR
# 1587                     Software Carpentry     NaN
# 1588                     Software Carpentry     NaN
# 1589                         self-organized      AU
#
# [1590 rows x 9 columns]

# %%
# Count number of values in each instructors cell
# See https://stackoverflow.com/questions/30202011/how-can-i-count-comma-separated-values-in-one-column-of-my-panda-table

# Convert the cell to list
# df['Category'] = df.Category.map(lambda x: [i.strip() for i in x.split(",")])
# Count values
# business['# Categories'] = business.Category.apply(len)


# Instructors are not included in this data set
# workshops['instructors'] = workshops.instructors.map(lambda x: [i.strip() for i in x.split(",")])
# workshops['count_instructors'] = workshops.instructors.apply(len)

# %% [markdown]
# ## Preview the whole dataframe

# %%
# Preview data

workshops
# Out:
#                                           slug    tag_name  month  year  day  \
# 0                           2011-11-07-toronto         SWC     11  2011    7
# 1582                       2018-08-15-stanford         SWC      8  2018   15
# 1583                            2018-08-21-ttt  TTT,online      8  2018   21
# 1584                           2018-08-23-LBNL          DC      8  2018   23
# 1585                            2018-08-28-ttt  TTT,online      8  2018   28
# 1586                          2018-09-24-CERTH         SWC      9  2018   24
# 1587                            2018-10-04-nyu         SWC     10  2018    4
# 1588                            2018-10-25-odu         SWC     10  2018   25
# 1589            datacarpentry_2015-11-23_VLSCI          DC     11  2015   23
#
#       attendance                                          host_name  \
# 0           22.0                              University of Toronto
# 1           14.0                  Space Telescope Science Institute
# 2           50.0       International Centre for Theoretical Physics
# 3           28.0                              University of Toronto
# 4           39.0                                 Indiana University
# 5           38.0           Monterey Bay Aquarium Research Institute
# 6           35.0                                              NERSC
# 7           35.0                              University of Chicago
# 8           32.0                              Utah State University
# 9           44.0                          University College London
# 10          55.0                          Michigan State University
# 11          41.0                            University of Newcastle
# 12          38.0                              University of Alberta
# 13          39.0                     University of British Columbia
# 14          20.0                           Johns Hopkins University
# 15          28.0                                      INRIA (Paris)
# 16          36.0              Massachusetts Institute of Technology
# 17          24.0            Science & Technology Facilities Council
# 18          40.0                             University of Waterloo
# 19          40.0                            Saint Mary's University
# 20          39.0                University of Toronto (Scarborough)
# 21          20.0                                 Software Carpentry
# 22          33.0                                    DAFX Conference
# 23          34.0                                 University of Oslo
# 24          39.0                                Columbia University
# 25          42.0                                  Purdue University
# 26          25.0                                 Software Carpentry
# 27          40.0              Lawrence Berkeley National Laboratory
# 28          62.0                     University of British Columbia
# 29          29.0                  University of California Berkeley
# ...          ...                                                ...
# 1560         NaN  King County Department of Community and Human ...
# 1561         NaN  Université Grenoble Alpes, Grenoble Alpes Data...
# 1562         NaN                                Griffith University
# 1563         NaN                                Griffith University
# 1564         NaN                Berkeley Institute for Data Science
# 1565         NaN                                 Software Carpentry
# 1566         NaN                                 Software Carpentry
# 1567         NaN                                          ELIXIR-UK
# 1568         NaN                                 Software Carpentry
# 1569         NaN                           University of Queensland
# 1570         NaN                                 Software Carpentry
# 1571         NaN                                 Software Carpentry
# 1572         NaN                                 Software Carpentry
# 1573         NaN              Lawrence Berkeley National Laboratory
# 1574         NaN                                 Software Carpentry
# 1575         NaN                         University of North Dakota
# 1576         NaN                                 Software Carpentry
# 1577         NaN                Berkeley Institute for Data Science
# 1578         NaN                                 Software Carpentry
# 1579         NaN              Lawrence Berkeley National Laboratory
# 1580         NaN                                 Software Carpentry
# 1581         NaN                                 Software Carpentry
# 1582         NaN                                Stanford University
# 1583         NaN                                 Software Carpentry
# 1584         NaN              Lawrence Berkeley National Laboratory
# 1585         NaN                                 Software Carpentry
# 1586         NaN       The Centre for Research & Technology, Hellas
# 1587         NaN                                New York University
# 1588         NaN                            Old Dominion University
# 1589        18.0                                              VLSCI
#
#                          administrator_name country
# 0                            Compute Canada      CA
# 1                        Software Carpentry      US
# 2                                  Cyfronet      IT
# 3                            Compute Canada      CA
# 4                        Software Carpentry      US
# 5                        Software Carpentry      US
# 6                        Software Carpentry      US
# 7                        Software Carpentry      US
# 8                        Software Carpentry      US
# 9     SSI Software Sustainability Institute      GB
# 10                       Software Carpentry      US
# 11    SSI Software Sustainability Institute      GB
# 12                           Compute Canada      CA
# 13                           Compute Canada      CA
# 14                       Software Carpentry      US
# 15                                 Cyfronet      FR
# 16                       Software Carpentry      US
# 17    SSI Software Sustainability Institute      GB
# 18                           Compute Canada      CA
# 19                           Compute Canada      CA
# 20                           Compute Canada      CA
# 21                       Software Carpentry      W3
# 22    SSI Software Sustainability Institute      GB
# 23                                 Cyfronet      NO
# 24                       Software Carpentry      US
# 25                       Software Carpentry      US
# 26                       Software Carpentry      W3
# 27                       Software Carpentry      US
# 28                           Compute Canada      CA
# 29                       Software Carpentry      US
# ...                                     ...     ...
# 1560                     Software Carpentry     NaN
# 1561                         self-organized      FR
# 1562                    Griffith University      AU
# 1563                    Griffith University      AU
# 1564                     Software Carpentry      US
# 1565                     Software Carpentry      W3
# 1566                     Software Carpentry     NaN
# 1567                         self-organized      BE
# 1568                     Software Carpentry      W3
# 1569                         self-organized      AU
# 1570                     Software Carpentry     NaN
# 1571                     Software Carpentry      W3
# 1572                     Software Carpentry      NO
# 1573                         Data Carpentry     NaN
# 1574                     Software Carpentry      W3
# 1575                         Data Carpentry     NaN
# 1576                     Software Carpentry     NaN
# 1577                     Software Carpentry      US
# 1578                     Software Carpentry     NaN
# 1579                     Software Carpentry     NaN
# 1580                     Software Carpentry      W3
# 1581                     Software Carpentry      W3
# 1582                     Software Carpentry     NaN
# 1583                     Software Carpentry      W3
# 1584                         Data Carpentry     NaN
# 1585                     Software Carpentry      W3
# 1586                         self-organized      GR
# 1587                     Software Carpentry     NaN
# 1588                     Software Carpentry     NaN
# 1589                         self-organized      AU
#
# [1590 rows x 9 columns]

# %%
def workshops_by_year(data, year): 
    """Takes a dataframe and a year, returns dataframe filtered by year"""
    df = pd.read_csv(data)
    df = df[df['year'] == year]
    return df

# %% [markdown]
# ## Select a year to see a dataframe of all workshops (across Carpentries) that year

# %%
# The interact function takes as arguments the function and that function's arguments separately
interact(workshops_by_year, data = 'workshops.csv', year = range(2011, 2019))
# Out:
# interactive(children=(Text(value='workshops.csv', description='data'), Dropdown(description='year', options=(2…
# <function __main__.workshops_by_year(data, year)>

# %%
def workshops_by_carpentry(data, carpentry): 
    """Takes a dataframe and a carpentry, returns dataframe filtered by that carpentry"""
    df = pd.read_csv(data)
    df = df[df['tag_name'].str.contains(carpentry)]
    return df

# %% [markdown]
# ## Select a Carpentry to see a dataframe of all workshops for that Carpentry (across all years)

# %%
interact(workshops_by_carpentry, data = 'workshops.csv', carpentry = ['SWC', 'DC', 'LC'])
# Out:
# interactive(children=(Text(value='workshops.csv', description='data'), Dropdown(description='carpentry', optio…
# <function __main__.workshops_by_carpentry(data, carpentry)>

# %%
def attendance_by_carpentry_and_year(data, carpentry): 
    """Takes a dataframe and a carpentry, returns attendance total by year for that carpentry as pandas series and bar plot"""
    df = pd.read_csv(data)
    df = df[df['tag_name'].str.contains(carpentry)]
    attendance_by_year = df.groupby('year')['attendance'].sum()
   
    attendance_list = attendance_by_year.tolist()
    
    offset = max(attendance_list) * .025
    ax = attendance_by_year.plot(x = 'year', y = 'attendance', kind = 'bar')
    for i in range(len(attendance_list)):
        ax.text(i, attendance_list[i] + offset, str(int(attendance_list[i])))
    plt.show()
    
    return attendance_by_year

# %% [markdown]
# ## Select a Carpentry to see a bar chart of attendance by year for that Carpentry
#
# This does not account for workshops missing attendance

# %%
interact(attendance_by_carpentry_and_year, data = 'workshops.csv', carpentry = ['SWC', 'DC', 'LC'])
# Out:
# interactive(children=(Text(value='workshops.csv', description='data'), Dropdown(description='carpentry', optio…
# <function __main__.attendance_by_carpentry_and_year(data, carpentry)>

# %%
def workshops_by_carpentry_and_year(data, carpentry="All", yr="All", stacked = True, agg="workshop count"): 
    """Takes a dataframe and a carpentry, returns dataframe filtered by that carpentry"""
    df = pd.read_csv(data)
    df.loc[df.administrator_name != 'self-organized', 'administrator_name'] = 'centrally'
    df.loc[df.administrator_name == 'self-organized', 'administrator_name'] = 'self'
    
    df.loc[df["tag_name"].str.contains("SWC"), 'tag_name'] = "SWC"
    df.loc[df["tag_name"].str.contains("DC"), 'tag_name'] = "DC"
    df.loc[df["tag_name"].str.contains("LC"), 'tag_name'] = "LC"
    df.loc[df["tag_name"].str.contains("TTT"), 'tag_name'] = "TTT"

    if carpentry != "All":
        df = df[df['tag_name'].str.contains(carpentry)]
    if yr != "All":
        df = df[df['year'] == year]
    
    if agg == "workshop count":
        attendance_by_year = df.groupby(['year', 'tag_name', 'administrator_name'])['slug'].count()
    elif agg == "attendance sum":
        attendance_by_year = df.groupby(['year', 'tag_name', 'administrator_name'])['attendance'].sum()

    attendance_by_year = attendance_by_year.to_frame()
    attendance_by_year.unstack().plot(kind='bar', stacked=stacked)

    return attendance_by_year

# %% [markdown]
# ## Select a Carpentry and year to see a bar chart of workshop count OR attendance total for that Carpentry/year and that bar chart's source dataframe by self organized and centrally organized workshops.  Select "stacked" to toggle stacked view or side by side view.
#
# This does not account for workshops missing attendance.  See here on how to fill na with means:
# https://chrisalbon.com/python/data_wrangling/pandas_missing_data/
#
# Need to figure out how to make the legends and labels more human readable.
#
# This is not currently accurate - we need to fix some data behind the scenes about whether workshops were self organized or centrally organized.

# %%
interact(workshops_by_carpentry_and_year, data = 'workshops.csv', stacked = [True, False], carpentry = ['All', 'SWC', 'DC', 'LC', 'TTT'], yr = ["All"] + list(range(2011, 2019)), agg=["attendance sum", "workshop count"])
# Out:
# interactive(children=(Text(value='workshops.csv', description='data'), Dropdown(description='carpentry', optio…
# <function __main__.workshops_by_carpentry_and_year(data, carpentry='All', yr='All', stacked=True, agg='workshop count')>
