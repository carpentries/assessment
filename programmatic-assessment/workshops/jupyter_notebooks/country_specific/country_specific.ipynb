# %%
# Choose a 2 character country code from:  US, CA, GB, NZ, AU
# This does not work when countries have null values (like MX has no DC workshops so it throws an error)

chosen_country = "AU"

# %%
## Import all the things

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import pycountry
import matplotlib.ticker as ticker
import datetime
# from scipy.stats import gaussian_kde
# from IPython.display import display, Markdown, Latex, display_markdown
from shapely.geometry import Point
# import folium
# from folium.plugins import HeatMap, HeatMapWithTime, MarkerCluster
# import os

# See plots in the notebook
# %matplotlib inline 

# This allows cells with long text values to wrap
pd.set_option('display.max_colwidth', -1)

pd.set_option('max_rows', 200)

# %%
# Load data for maps

# bounding box
bbox = gpd.read_file("../../data_files/spatial-vector-lidar/global/ne_110m_graticules_all/ne_110m_wgs84_bounding_box.shp")
bbox_robinson = bbox.to_crs('+proj=robin')


# world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')).to_crs(epsg=4326) #.to_crs('+proj=robin') # world map
world_robinson = world.to_crs('+proj=robin')


# Define constants - this will change with each report publication
report_date = pd.Timestamp(2018, 9, 30)

# %%
# Functions to clean up data

def get_country_name(alpha2_code):
    
    '''
    Takes a two character country code and
    returns the full name of the country.
    '''

    try:
        return pycountry.countries.get(alpha_2=alpha2_code).name
#         return pycountry.countries.
    except KeyError:
        if alpha2_code == "W3":
            return "online"
        else:
            return "unknown"
        
        
def get_country_code3(alpha2_code):
    
    '''
    Takes a two character country code and
    returns the full name of the country.
    '''

    try:
        return pycountry.countries.get(alpha_2=alpha2_code).alpha_3
#         return pycountry.countries.
    except KeyError:
        if alpha2_code == "W3":
            return "online"
        else:
            return "unknown"
        
        
# Function to create dataframes of counts and percentages by category (previous experience, expertise)
# when option is check many 
def get_value_counts_many(df, col_name, value_list):
    """
    Takes the parameters:
    * dataframe
    * the column in the df you want to group and count by
    * The list of characteristics (to ensure sort order)

    Returns a two column dataframe that has the grouped column and the count by that column

    
    """    
    
    df_counts = pd.DataFrame(columns=[col_name, 'Count'])
    
    for v in value_list:
#         count = df[col_name].apply(lambda x:x.count(v)).sum()
        count = df[col_name].str.count(v).sum()
        df_counts.loc[len(df_counts)] = [v, count]
        
    return df_counts

# %%
# Load csv into df, filter just GB workshops

all_events = pd.read_csv("../../data_files/all_workshops.csv", keep_default_na=False, na_values=[''])
all_events = all_events[all_events.country == chosen_country].copy()
# display(all_events)


####
# Replace country codes with full country name
# Set distinct workshop type (SWC, DC, LC, TTT)
# Set NaN attendance data to zero
# Convert workshop dates to date format
# Get just the regular workshops (not TTT events, not onboarding events, etc)
##### 

all_events.rename(columns={"country": "country2",}, inplace=True)



# Apply the function to get the full country name
all_events['country'] = all_events['country2'].apply(get_country_name)
all_events['country3'] = all_events['country2'].apply(get_country_code3)


# display(all_events)

# Clean up the tag names
# Create a new column for "workshop_type"; populate it SWC, DC, LC, or TTT
# Remove the old "tag_name" column
all_events.loc[all_events['tag_name'].str.contains("SWC"), "workshop_type"] = "SWC"
all_events.loc[all_events['tag_name'].str.contains("DC"), "workshop_type"] = "DC"
all_events.loc[all_events['tag_name'].str.contains("LC"), "workshop_type"] = "LC"
all_events.loc[all_events['tag_name'].str.contains("TTT"), "workshop_type"] = "TTT"
all_events = all_events.drop('tag_name', axis=1)

# Clean up attendance value - this is inconsistently stored as NaN or 0
# All zero values should be NaN
all_events['attendance'] =  all_events['attendance'].replace(0.0, np.nan)

# Date data type
all_events['start_date'] = pd.to_datetime(all_events['start_date'])


report_date = pd.Timestamp(2018, 10, 31)

# Remove events before report date
all_events = all_events[all_events['start_date'] < report_date]

# Remove instructor training events; these will be analyzed separately.
# Limit to non TTT workshops
workshops = all_events[all_events['workshop_type'] != "TTT"]

# Remove online events like maintainer onboarding
workshops = workshops.drop(workshops[workshops.country == "online"].index)

display(workshops)
# Out:
#                                               slug start_date  attendance  \
# 53    2013-02-07-macquarie                         2013-02-07  38.0
# 54    2013-02-14-amos                              2013-02-14  68.0
# 117   2013-09-24-acpfgA                            2013-09-24  20.0
# 121   2013-10-01-acpfgM                            2013-10-01  27.0
# 123   2013-10-09-canberra                          2013-10-09  35.0
# 132   2013-11-25-unimelb                           2013-11-25  36.0
# 153   2014-02-10-hobart                            2014-02-10  37.0
# 155   2014-02-13-UNSW                              2014-02-13  38.0
# 158   2014-02-18-UTS                               2014-02-18  29.0
# 168   2014-03-18-combine                           2014-03-18  42.0
# 196   2014-06-02-monash                            2014-06-02  36.0
# 228   2014-07-30-pyconaus                          2014-07-30  40.0
# 234   2014-08-18-unimelb                           2014-08-18  45.0
# 246   2014-09-15-unimelb                           2014-09-15  44.0
# 264   2014-10-31-USyd                              2014-10-31  27.0
# 280   2014-12-08-combine-r                         2014-12-08  42.0
# 318   2015-02-16-resbaz-matlab                     2015-02-16  17.0
# 319   2015-02-16-resbaz-python                     2015-02-16  47.0
# 320   2015-02-16-resbaz-r                          2015-02-16  43.0
# 347   2015-04-08-SWC-UniMelb-Biosciences           2015-04-08  42.0
# 367   2015-05-04-matlab                            2015-05-04  17.0
# 368   2015-05-04-swinpython                        2015-05-04  28.0
# 377   2015-05-25-unimelb                           2015-05-25  24.0
# 392   2015-06-08-matlab                            2015-06-08  22.0
# 420   2015-06-29-qaeco-unimelb                     2015-06-29  21.0
# 422   2015-07-02-UQ                                2015-07-02  39.0
# 423   2015-07-02-monash                            2015-07-02  35.0
# 427   2015-07-13-amos                              2015-07-13  24.0
# 429   2015-07-13-unimelb                           2015-07-13  22.0
# 434   2015-07-20-perth                             2015-07-20  19.0
# 445   2015-08-05-UWS                               2015-08-05  15.0
# 474   2015-09-10-SWC-ANU                           2015-09-10  41.0
# 480   2015-09-17-WSU                               2015-09-17  17.0
# 494   2015-09-28-UQ                                2015-09-28  38.0
# 497   2015-09-28-unimelb-r-psychology              2015-09-28  23.0
# 498   2015-10-01-CPCEMCR                           2015-10-01  20.0
# 499   2015-10-01-JamesCookUni                      2015-10-01  23.0
# 505   2015-10-07-R-Data-Sydney                     2015-10-07  19.0
# 510   2015-10-17-IEEE-Python                       2015-10-17  27.0
# 531   2015-11-05-CSU                               2015-11-05  5.0
# 553   2015-11-23-ccrc                              2015-11-22  30.0
# 557   2015-11-26-adelaide-python                   2015-11-26  42.0
# 560   2015-12-01-uow                               2015-12-01  14.0
# 562   2015-12-07-Python-for-Science                2015-12-07  38.0
# 568   2015-12-08-USYD                              2015-12-08  22.0
# 569   2015-12-09-TRI                               2015-12-09  24.0
# 573   2015-12-14-Python-for-Researchers            2015-12-14  31.0
# 617   2016-02-01-BrisbaneResBaz-Python             2016-02-01  32.0
# 618   2016-02-01-BrisbaneResBaz-R                  2016-02-01  34.0
# 619   2016-02-01-ResBaz                            2016-02-01  22.0
# 620   2016-02-01-ResBaz-Sydney-RBeginner           2016-02-01  15.0
# 622   2016-02-01-perth                             2016-02-01  78.0
# 623   2016-02-01-python-resbaz-2016                2016-02-01 NaN
# 624   2016-02-01-rezbazsydneypython                2016-02-01  23.0
# 675   2016-03-30-Python-for-Positive-Psychology    2016-03-29  58.0
# 676   2016-03-31-UNSW                              2016-03-31  27.0
# 682   2016-04-06-UON                               2016-04-06  22.0
# 684   2016-04-11-dsiti                             2016-04-11  16.0
# 686   2016-04-12-UTS                               2016-04-12  21.0
# 695   2016-04-18-USYD                              2016-04-18  18.0
# 698   2016-04-19-GriffithUni                       2016-04-19  22.0
# 718   2016-05-12-CharlesDarwinUni                  2016-05-12 NaN
# 743   2016-05-31-CQU-R                             2016-05-31  11.0
# 752   2016-06-06-GriffithUni-Python                2016-06-06 NaN
# 771   2016-06-16-VetSciUnimelb                     2016-06-16  38.0
# 776   2016-06-21-LTU                               2016-06-21  10.0
# 791   2016-07-11-UNSW                              2016-07-11  26.0
# 794   2016-07-11-bne-R                             2016-07-11  1.0
# 798   2016-07-18-curtin                            2016-07-18 NaN
# 799   2016-07-18-usq                               2016-07-18 NaN
# 801   2016-07-20-UTS_Library_Data_Carpentry        2016-07-12  40.0
# 809   2016-08-02-dsiti                             2016-08-02 NaN
# 813   2016-08-05-hobart                            2016-08-26  45.0
# 817   2016-08-10-Pre-Pycon_Data_Carpentry_Workshop 2016-08-10  33.0
# 821   2016-08-16-WSU                               2016-08-16 NaN
# 854   2016-09-14-GriffithUni-Python                2016-09-14 NaN
# 864   2016-09-21-UON                               2016-09-21 NaN
# 868   2016-09-26-usq                               2016-09-26 NaN
# 869   2016-09-27-SoftwareCarpentry-tsv             2016-09-27 NaN
# 870   2016-09-27-UNSW                              2016-09-27 NaN
# 872   2016-09-28-GriffithUni-R                     2016-09-28 NaN
# 882   2016-10-05-LTU                               2016-10-05 NaN
# 886   2016-10-06-QBI                               2016-10-06 NaN
# 907   2016-10-25-uwa                               2016-10-25  35.0
# 924   2016-11-07-Curtin                            2016-11-07  26.0
# 934   2016-11-14-unimelb                           2016-11-14  9.0
# 944   2016-11-29-qut                               2016-11-29  31.0
# 954   2016-12-12-Deakin                            2016-12-12 NaN
# 986   2017-01-30-NeuRA-Python                      2017-01-30  23.0
# 987   2017-01-31-resbaztas-python                  2017-01-31  40.0
# 988   2017-01-31-resbaztas-r                       2017-01-31  50.0
# 996   2017-02-05-amos                              2017-02-05  17.0
# 1015  2017-02-27-UTS                               2017-02-27  25.0
# 1017  2017-03-02-SoftwareCarpentry-tsv             2017-03-02 NaN
# 1030  2017-03-16-SoftwareCarpentryPy-TSV           2017-03-16  24.0
# 1047  2017-04-06-DataCarpentry-Genomics-TSV        2017-04-06 NaN
# 1052  2017-04-10-GriffithUni-Python                2017-04-10  24.0
# 1055  2017-04-12-GriffithUni-Git                   2017-04-12  32.0
# 1056  2017-04-20-SWC-Melbourne                     2017-04-20  25.0
# 1086  2017-05-17-qbi                               2017-05-17  17.0
# 1088  2017-05-18-R-Macquarie                       2017-05-18  18.0
# 1102  2017-05-29-GriffithUni-R                     2017-05-29  27.0
# 1107  2017-06-06-Curtin                            2017-06-06  23.0
# 1117  2017-06-15-uow                               2017-06-15  19.0
# 1139  2017-07-03-ResBaz-Python                     2017-07-03 NaN
# 1140  2017-07-03-ResBaz-R                          2017-07-03 NaN
# 1143  2017-07-03-sydney-resbaz-r-novice            2017-07-03  25.0
# 1148  2017-07-10-uqws                              2017-07-10  31.0
# 1167  2017-07-27-hobart                            2017-07-27  45.0
# 1175  2017-08-01-resbazp                           2017-02-08  37.0
# 1176  2017-08-01-resbazr                           2017-02-08  38.0
# 1189  2017-08-10-qbi                               2017-08-10  9.0
# 1205  2017-08-21-GriffithUni-R                     2017-08-21  22.0
# 1210  2017-08-28-curtin                            2017-08-28  28.0
# 1214  2017-08-31-MacquarieUniversity               2017-08-31  16.0
# 1237  2017-09-25-usq                               2017-09-25 NaN
# 1239  2017-09-26-MacquarieUniversity               2017-09-26  16.0
# 1290  2017-10-31-qut                               2017-10-31  34.0
# 1302  2017-11-07-curtin                            2017-11-07  23.0
# 1317  2017-11-23-GriffithUni-Python                2017-11-23  24.0
# 1318  2017-11-27-USyd-Python                       2017-11-27  12.0
# 1333  2017-12-12-MQU-R                             2017-12-12  34.0
# 1375  2018-01-23-uwa                               2018-01-23  54.0
# 1387  2018-02-04-amos-icshmo                       2018-02-04  40.0
# 1390  2018-02-07-GriffithUni-Python                2018-02-07  13.0
# 1400  2018-02-20-MQU-DC                            2018-02-20  39.0
# 1401  2018-02-20-qut                               2018-02-20  12.0
# 1447  2018-03-19-curtin                            2018-03-19  28.0
# 1475  2018-04-11-GriffithUni-R                     2018-04-11  22.0
# 1489  2018-04-23-curtin                            2018-04-23  39.0
# 1499  2018-04-26-WEHI                              2018-04-26  27.0
# 1517  2018-05-10-macquarie-university              2018-05-10  28.0
# 1546  2018-06-06-ResbazBris-Python                 2018-06-06  30.0
# 1547  2018-06-06-ResbazBris-R                      2018-06-06  30.0
# 1560  2018-06-12-wrds                              2018-06-12  15.0
# 1591  2018-06-28-uqws                              2018-06-28  32.0
# 1594  2018-07-03-ResBazPythonIntro                 2018-07-03  48.0
# 1595  2018-07-03-ResbazSydney                      2018-07-03  62.0
# 1597  2018-07-03-resbaz-python-advanced            2018-07-03  37.0
# 1598  2018-07-03-resbaz-sydneyAdvR                 2018-07-03  37.0
# 1599  2018-07-03-resbaz2018sql                     2018-07-03  27.0
# 1609  2018-07-16-curtin                            2018-07-16  30.0
# 1657  2018-08-28-qut                               2018-08-28  27.0
# 1687  2018-09-18-mq-python                         2018-09-18  35.0
# 1711  2018-10-02-usq                               2018-10-02  33.0
# 1718  2018-10-08-GriffithUni-Python                2018-10-08  25.0
# 1757  2018-10-29-MacquarieUniversity               2018-10-29  29.0
# 1868  datacarpentry_2015-11-23_VLSCI               2015-11-23  18.0
#
#                                                          host_name country2  \
# 53    Macquarie University                                          AU
# 54    AMOS Conference (Melbourne)                                   AU
# 117   Australian Centre for Plant Functional Genomics               AU
# 121   Australian Centre for Plant Functional Genomics               AU
# 123   Australian National University                                AU
# 132   University of Melbourne                                       AU
# 153   AMOS Conference (Melbourne)                                   AU
# 155   University of New South Wales                                 AU
# 158   University of Technology Sydney                               AU
# 168   University of Melbourne                                       AU
# 196   Monash University                                             AU
# 228   University of Queensland                                      AU
# 234   University of Melbourne                                       AU
# 246   University of Melbourne                                       AU
# 264   University of Sydney                                          AU
# 280   University of Melbourne                                       AU
# 318   University of Melbourne                                       AU
# 319   University of Melbourne                                       AU
# 320   University of Melbourne                                       AU
# 347   University of Melbourne                                       AU
# 367   University of Melbourne                                       AU
# 368   Swinburne University of Technology                            AU
# 377   University of Melbourne                                       AU
# 392   University of Melbourne                                       AU
# 420   University of Melbourne                                       AU
# 422   University of Queensland                                      AU
# 423   Monash University                                             AU
# 427   University of Queensland                                      AU
# 429   University of Melbourne                                       AU
# 434   Curtin University                                             AU
# 445   Intersect Australia                                           AU
# 474   Australian National University                                AU
# 480   Intersect Australia                                           AU
# 494   University of Queensland                                      AU
# 497   University of Melbourne                                       AU
# 498   University of Sydney                                          AU
# 499   James Cook University                                         AU
# 505   University of Sydney                                          AU
# 510   University of Melbourne                                       AU
# 531   Charles Sturt University                                      AU
# 553   University of New South Wales                                 AU
# 557   University of Adelaide                                        AU
# 560   University of Wollongong                                      AU
# 562   University of Melbourne                                       AU
# 568   University of Sydney                                          AU
# 569   Translational Research Institute                              AU
# 573   University of Melbourne                                       AU
# 617   Queensland University of Technology                           AU
# 618   Queensland University of Technology                           AU
# 619   University of Sydney                                          AU
# 620   University of Sydney                                          AU
# 622   Curtin University                                             AU
# 623   University of Melbourne                                       AU
# 624   University of Sydney                                          AU
# 675   University of Melbourne                                       AU
# 676   Intersect Australia                                           AU
# 682   Intersect Australia                                           AU
# 684   Department of Science, Information Technology and Innovation  AU
# 686   Intersect Australia                                           AU
# 695   Intersect Australia                                           AU
# 698   Griffith University                                           AU
# 718   Charles Darwin University                                     AU
# 743   CQUniversity                                                  AU
# 752   Griffith University                                           AU
# 771   COMBINE                                                       AU
# 776   Intersect Australia                                           AU
# 791   Intersect Australia                                           AU
# 794   University of Queensland                                      AU
# 798   Curtin University                                             AU
# 799   University of Southern Queensland                             AU
# 801   University of Melbourne                                       AU
# 809   Department of Science, Information Technology and Innovation  AU
# 813   Data Science Hobart                                           AU
# 817   VLSCI                                                         AU
# 821   Intersect Australia                                           AU
# 854   Griffith University                                           AU
# 864   Intersect Australia                                           AU
# 868   University of Southern Queensland                             AU
# 869   James Cook University                                         AU
# 870   Intersect Australia                                           AU
# 872   Griffith University                                           AU
# 882   Intersect Australia                                           AU
# 886   University of Queensland                                      AU
# 907   University of Western Australia                               AU
# 924   Curtin University                                             AU
# 934   ARC Centre of Excellence for Climate System Science           AU
# 944   Queensland University of Technology                           AU
# 954   Intersect Australia                                           AU
# 986   Neuroscience Research Australia                               AU
# 987   Data Science Hobart                                           AU
# 988   Data Science Hobart                                           AU
# 996   Australian Meteorological and Oceanographic Society           AU
# 1015  University of Technology Sydney                               AU
# 1017  James Cook University                                         AU
# 1030  James Cook University                                         AU
# 1047  James Cook University                                         AU
# 1052  Griffith University                                           AU
# 1055  Griffith University                                           AU
# 1056  COMBINE                                                       AU
# 1086  University of Queensland                                      AU
# 1088  Macquarie University                                          AU
# 1102  Griffith University                                           AU
# 1107  Curtin University                                             AU
# 1117  University of Wollongong                                      AU
# 1139  Intersect Australia                                           AU
# 1140  Intersect Australia                                           AU
# 1143  Macquarie University                                          AU
# 1148  University of Queensland                                      AU
# 1167  Data Science Hobart                                           AU
# 1175  University of Queensland                                      AU
# 1176  University of Queensland                                      AU
# 1189  University of Queensland                                      AU
# 1205  Griffith University                                           AU
# 1210  Curtin University                                             AU
# 1214  Macquarie University                                          AU
# 1237  University of Southern Queensland                             AU
# 1239  Macquarie University                                          AU
# 1290  Queensland University of Technology                           AU
# 1302  Curtin University                                             AU
# 1317  Griffith University                                           AU
# 1318  University of Sydney                                          AU
# 1333  Macquarie University                                          AU
# 1375  Curtin University                                             AU
# 1387  Australian Meteorological and Oceanographic Society           AU
# 1390  Griffith University                                           AU
# 1400  Macquarie University                                          AU
# 1401  Queensland University of Technology                           AU
# 1447  Curtin University                                             AU
# 1475  Griffith University                                           AU
# 1489  Curtin University                                             AU
# 1499  COMBINE                                                       AU
# 1517  Macquarie University                                          AU
# 1546  Griffith University                                           AU
# 1547  Griffith University                                           AU
# 1560  University of Queensland                                      AU
# 1591  University of Queensland                                      AU
# 1594  Macquarie University                                          AU
# 1595  Macquarie University                                          AU
# 1597  Macquarie University                                          AU
# 1598  Macquarie University                                          AU
# 1599  Macquarie University                                          AU
# 1609  Curtin University                                             AU
# 1657  Queensland University of Technology                           AU
# 1687  Macquarie University                                          AU
# 1711  Queensland Cyber Infrastructure Foundation                    AU
# 1718  Griffith University                                           AU
# 1757  Macquarie University                                          AU
# 1868  VLSCI                                                         AU
#
#        latitude   longitude  \
# 53   -33.773636  151.112005
# 54   -37.825328  144.951621
# 117  -34.919159  138.604140
# 121  -37.908300  145.138000
# 123  -35.277700  149.118530
# 132  -37.796300  144.961400
# 153  -42.880600  147.325000
# 155  -33.917410  151.231307
# 158  -33.883898  151.201013
# 168  -37.796300  144.961400
# 196  -37.915211  145.134682
# 228  -27.501420  153.015150
# 234  -37.796300  144.961400
# 246  -37.796300  144.961400
# 264  -33.887526  151.190262
# 280  -37.800138  144.959285
# 318  -37.799243  144.964422
# 319  -37.799243  144.964422
# 320  -37.799243  144.964422
# 347  -37.800265  144.959805
# 367  -37.799243  144.964422
# 368  -37.821771  145.038931
# 377  -37.792910  144.961174
# 392  -37.800483  144.965807
# 420  -37.800091  144.959021
# 422  -27.501425  153.014930
# 423  -37.912270  145.132756
# 427  -27.497257  153.014473
# 429  -37.797738  144.960107
# 434  -31.994450  115.885636
# 445  -33.810273  151.024438
# 474  -35.277700  149.118527
# 480  -33.810273  151.024438
# 494  -27.501425  153.014930
# 497  -37.800091  144.959021
# 498  -33.887261  151.183828
# 499  -19.329376  146.760334
# 505  -33.887674  151.190280
# 510  -37.792910  144.961174
# 531  -35.064656  147.359956
# 553  -33.917763  151.234260
# 557  -34.919136  138.604870
# 560  -34.405678  150.881178
# 562  -37.797915  144.959933
# 568  -33.887037  151.180855
# 569  -27.498869  153.031914
# 573  -37.792910  144.961174
# 617  -27.476664  153.027965
# 618  -27.476664  153.027965
# 619  -33.888009  151.186698
# 620  -33.887371  151.190656
# 622  -32.066462  115.830142
# 623  -37.797915  144.959933
# 624  -33.887348  151.190090
# 675  -37.803975  144.960809
# 676  -33.918488  151.227858
# 682  -32.893143  151.698135
# 684  -27.494863  153.028149
# 686  -33.880858  151.201299
# 695  -33.887362  151.188741
# 698  -27.552079  153.054078
# 718  -12.372200  130.868900
# 743  -23.324108  150.519452
# 752  -27.962224  153.381897
# 771  -37.797664  144.953251
# 776  -37.720935  145.048445
# 791  -33.918488  151.227858
# 794  -27.501425  153.014930
# 798  -32.007532  115.894223
# 799  -27.606578  151.935113
# 801  -33.880842  151.202238
# 809  -27.500077  153.014352
# 813  -42.886048  147.335837
# 817  -37.800146  144.964346
# 821  -33.811304  151.024265
# 854  -27.552941  153.052425
# 864  -32.892772  151.704177
# 868  -27.606578  151.935113
# 869  -19.329383  146.759118
# 870  -33.918488  151.227858
# 872  -27.552941  153.052425
# 882  -36.112302  146.850954
# 886  -27.499389  153.011573
# 907  -31.979177  115.817742
# 924  -32.007532  115.894223
# 934  -37.797168  144.965215
# 944  -27.477586  153.027958
# 954  -38.197907  144.298132
# 986  -33.868820  151.209296
# 987  -42.886048  147.335837
# 988  -42.886048  147.335837
# 996  -35.277682  149.115448
# 1015 -33.883997  151.199156
# 1017 -19.329383  146.759118
# 1030 -19.329383  146.759118
# 1047 -19.260262  146.815951
# 1052 -27.962224  153.381897
# 1055 -27.552941  153.052425
# 1056 -37.796897  144.957442
# 1086 -27.499542  153.011805
# 1088 -33.774238  151.118633
# 1102 -27.552941  153.052425
# 1107 -32.007969  115.892742
# 1117 -34.405710  150.881288
# 1139 -33.880954  151.201288
# 1140 -33.880954  151.201288
# 1143 -33.880910  151.199099
# 1148 -27.501425  153.014930
# 1167 -42.886048  147.335837
# 1175 -27.499480  153.013104
# 1176 -27.499480  153.013104
# 1189 -27.499542  153.011805
# 1205 -27.552941  153.052425
# 1210 -32.007969  115.892742
# 1214 -33.774675  151.113344
# 1237 -27.606578  151.935113
# 1239 -33.774675  151.113344
# 1290 -27.477356  153.028423
# 1302 -32.006963  115.894348
# 1317 -27.962224  153.381897
# 1318 -33.888226  151.188702
# 1333 -33.774693  151.112323
# 1375 -31.985918  115.820776
# 1387 -33.917729  151.234230
# 1390 -27.962224  153.381897
# 1400 -33.775015  151.112545
# 1401 -27.456061  153.013368
# 1447 -32.006195  115.894418
# 1475 -27.552941  153.052425
# 1489 -32.006195  115.894418
# 1499 -37.796897  144.957442
# 1517 -33.774715  151.113321
# 1546 -27.482034  153.024804
# 1547 -27.482034  153.024804
# 1560 -27.515301  152.966883
# 1591 -27.501479  153.012728
# 1594 -33.773824  151.112650
# 1595 -33.775541  151.112154
# 1597 -33.775119  151.114699
# 1598 -33.773949  151.114946
# 1599 -33.775541  151.114343
# 1609 -32.006919  115.892092
# 1657 -27.477340  153.028414
# 1687 -33.775082  151.113010
# 1711 -27.684010  152.907227
# 1718 -27.960345  153.378868
# 1757 -33.774804  151.113281
# 1868 -37.800189  144.964362
#
#                                                                                 url  \
# 53    https://swcarpentry.github.io/2013-02-07-macquarie/
# 54    https://swcarpentry.github.io/2013-02-14-amos/
# 117   https://swcarpentry.github.io/2013-09-24-acpfgA/
# 121   https://swcarpentry.github.io/2013-10-01-acpfgM/
# 123   https://swcarpentry.github.io/2013-10-09-canberra/
# 132   https://damienirving.github.io/2013-11-25-unimelb/
# 153   https://damienirving.github.io/2014-02-10-hobart/
# 155   https://nicercode.github.io/2014-02-13-UNSW/
# 158   https://nicercode.github.io/2014-02-18-UTS/
# 168   https://resbaz.github.io/2014-03-18-combine/
# 196   https://badger-d.github.io/2014-06-02-monash/
# 228   https://philippbayer.github.io/2014-07-30-pyconaus/
# 234   https://resbaz.github.io/2014-08-18-unimelb/
# 246   https://resbaz.github.io/2014-09-15-unimelb/
# 264   https://dbarneche.github.io/2014-10-31-USyd/
# 280   https://resbaz.github.io/2014-12-08-combine-r/
# 318   https://resbaz.github.io/2015-02-16-resbaz-matlab/
# 319   https://resbaz.github.io/2015-02-16-resbaz-python/
# 320   https://resbaz.github.io/2015-02-16-resbaz-r/
# 347   https://COMBINE-Australia.github.io/2015-04-08-SWC-UniMelb-Biosciences/
# 367   https://resbaz.github.io/2015-05-04-matlab/
# 368   https://drarnakarick.github.io/2015-05-04-swinpython/
# 377   https://resbaz.github.io/2015-05-25-unimelb/
# 392   https://resbaz.github.io/2015-06-08-matlab/
# 420   https://resbaz.github.io/2015-06-29-qaeco-unimelb/
# 422   https://bio-swc-bne.github.io/2015-07-02-UQ/
# 423   https://MonashBioinformaticsPlatform.github.io/2015-07-02-monash/
# 427   https://damienirving.github.io/2015-07-13-amos/
# 429   https://resbaz.github.io/2015-07-13-unimelb/
# 434   https://arohl.github.io/2015-07-20-perth/
# 445   https://intersectaustralia.github.io/2015-08-05-UWS/
# 474   https://combine-australia.github.io/2015-09-10-SWC-ANU/
# 480   https://IntersectAustralia.github.io/2015-09-17-WSU/
# 494   https://bio-swc-bne.github.io/2015-09-28-UQ/
# 497   https://resbaz.github.io/2015-09-28-unimelb-r-psychology/
# 498   https://fpheld.github.io/2015-10-01-CPCEMCR/
# 499   https://jcu-eresearch.github.io/2015-10-01-JamesCookUni/
# 505   https://combine-australia.github.io/2015-10-07-R-Data-Sydney/
# 510   https://resbaz.github.io/2015-10-17-IEEE-Python/
# 531   https://intersectaustralia.github.io/2015-11-05-CSU/
# 553   https://nicjhan.github.io/2015-11-23-ccrc/
# 557   http://COMBINE-Australia.github.io/2015-11-26-adelaide-python
# 560   https://benmarwick.github.io/2015-12-01-uow/
# 562   https://resbaz.github.io/2015-12-07-Python-for-Science/
# 568   http://intersectaustralia.github.io/2015-12-08-USYD/
# 569   https://bio-swc-bne.github.io/2015-12-09-TRI/
# 573   https://resbaz.github.io/2015-12-14-Python-for-Researchers/
# 617   http://bio-swc-bne.github.io/2016-02-01-BrisbaneResBaz-Python/
# 618   http://bio-swc-bne.github.io/2016-02-01-BrisbaneResBaz-R/
# 619   http://nicercode.github.io/2016-02-01-ResBaz/
# 620   http://fpheld.github.io/2016-02-01-ResBaz-Sydney-RBeginner/
# 622   http://raffademichelis.github.io/2016-02-01-perth/
# 623   http://resbaz.github.io/python-resbaz-2016/
# 624   http://daryavanichkina.com/2016-02-01-rezbazsydneypython/
# 675   http://alistairwalsh.github.io/2016-03-30-Python-for-Positive-Psychology/
# 676   http://intersectaustralia.github.io/2016-03-31-UNSW/
# 682   http://intersectaustralia.github.io/2016-04-06-UON/
# 684   https://bio-swc-bne.github.io/2016-04-11-dsiti/
# 686   http://jberghold.github.io/2016-04-12-UTS/
# 695   http://intersectaustralia.github.io/2016-04-18-USYD/
# 698   https://bio-swc-bne.github.io/2016-04-19-GriffithUni/
# 718   http://combine-australia.github.io/2016-05-12-CharlesDarwinUni/
# 743   https://bio-swc-bne.github.io/2016-05-31-CQU-R/index.html
# 752   https://bio-swc-bne.github.io/2016-06-06-GriffithUni-Python/
# 771   http://combine-australia.github.io/2016-06-16-VetSciUnimelb/
# 776   https://intersectaustralia.github.io/2016-06-21-LTU/
# 791   https://intersectaustralia.github.io/2016-07-11-UNSW/
# 794   https://bio-swc-bne.github.io/2016-07-11-bne-R/
# 798   http://curtinic.github.io/SWC-2016-07-18/
# 799   https://fgacenga.github.io/2016-07-18-usq/
# 801   https://alistairwalsh.github.io/2016-07-20-UTS_Library_Data_Carpentry/
# 809   https://bio-swc-bne.github.io/2016-08-02-dsiti
# 813   https://datasciencehobart.github.io/2016-08-05-hobart/
# 817   https://alistairwalsh.github.io/2016-08-10-Pre-Pycon_Data_Carpentry_Workshop/
# 821   https://intersectaustralia.github.io/2016-08-16-WSU/
# 854   https://bio-swc-bne.github.io/2016-09-14-GriffithUni-Python/
# 864   https://intersectaustralia.github.io/2016-09-21-UON/
# 868   https://fgacenga.github.io/2016-09-26-usq/
# 869   https://jcu-eresearch.github.io/2016-09-27-SoftwareCarpentry-tsv/
# 870   https://intersectaustralia.github.io/2016-09-27-UNSW/
# 872   https://bio-swc-bne.github.io/2016-09-28-GriffithUni-R/
# 882   https://intersectaustralia.github.io/2016-10-05-LTU/
# 886   https://bio-swc-bne.github.io/2016-10-06-QBI/
# 907   https://philippbayer.github.io/2016-10-25-uwa/
# 924   https://curtinic.github.io/SWC-2016-11-07-Curtin/
# 934   https://nicjhan.github.io/2016-11-14-unimelb/
# 944   https://bio-swc-bne.github.io/2016-11-29-qut/
# 954   http://intersectaustralia.github.io/2016-12-12-Deakin
# 986   https://martinheroux.github.io/2017-01-30-NeuRA-Python/
# 987   https://datasciencehobart.github.io/2017-01-31-resbaztas-python/
# 988   https://datasciencehobart.github.io/2017-01-31-resbaztas-r/
# 996   https://damienirving.github.io/2017-02-05-amos/
# 1015  http://daryavanichkina.com/2017-02-27-UTS/
# 1017  https://jcu-eresearch.github.io/2017-03-02-SoftwareCarpentry-tsv/
# 1030  https://jcu-eresearch.github.io/2017-03-16-SoftwareCarpentryPy-TSV/
# 1047  https://jcu-eresearch.github.io/2017-04-06-DataCarpentry-Genomics-TSV
# 1052  https://bio-swc-bne.github.io/2017-04-10-GriffithUni-Python/
# 1055  https://bio-swc-bne.github.io/2017-04-12-GriffithUni-Git
# 1056  https://combine-australia.github.io/2017-04-20-SWC-Melbourne/
# 1086  https://lizcw.github.io/2017-05-17-qbi/
# 1088  https://martinheroux.github.io/2017-05-18-R-Macquarie/
# 1102  https://bio-swc-bne.github.io/2017-05-29-GriffithUni-R/
# 1107  https://curtinic.github.io/SWC-2017-06-06-Curtin/
# 1117  https://benmarwick.github.io/2017-06-15-uow/
# 1139  https://intersectaustralia.github.io/2017-07-03-ResBaz-Python/
# 1140  https://intersectaustralia.github.io/2017-07-03-ResBaz-R/
# 1143  https://jduckles.github.io/2017-07-03-sydney-resbaz-r-novice/
# 1148  https://bio-swc-bne.github.io/2017-07-10-uqws/
# 1167  https://datatas.github.io/2017-07-27-hobart/
# 1175  https://bio-swc-bne.github.io/2017-08-01-resbazp/
# 1176  https://bio-swc-bne.github.io/2017-08-01-resbazr/
# 1189  https://lizcw.github.io/2017-08-10-qbi/
# 1205  https://bio-swc-bne.github.io/2017-08-21-GriffithUni-R/
# 1210  https://curtinic.github.io/SWC-CIC/
# 1214  https://denubis.github.io/2017-08-31-MacquarieUniversity/
# 1237  https://fgacenga.github.io/2017-09-25-usq/index.html
# 1239  https://denubis.github.io/2017-09-26-MacquarieUniversity/
# 1290  https://weaverbel.github.io/2017-10-31-qut/
# 1302  https://curtinic.github.io/2017-11-07-curtin/
# 1317  https://bio-swc-bne.github.io/2017-11-23-GriffithUni-Python/
# 1318  https://joannadiong.github.io/2017-11-27-USyd-Python/
# 1333  https://adivea.github.io/2017-12-12-MQU-R/
# 1375  https://resbaz.github.io/resbaz2018/perth/
# 1387  https://damienirving.github.io/2018-02-04-amos-icshmo/
# 1390  https://bio-swc-bne.github.io/2018-02-07-GriffithUni-Python/
# 1400  https://adivea.github.io/2018-02-20-MQU-DC/
# 1401  https://stapleto.github.io/2018-02-20-qut/
# 1447  https://curtinic.github.io/2018-03-19-curtin/
# 1475  https://bio-swc-bne.github.io/2018-04-11-GriffithUni-R/
# 1489  https://curtinic.github.io/2018-04-23-curtin/
# 1499  https://combine-australia.github.io/2018-4-26-SWC-Melbourne/
# 1517  https://mq-software-carpentry.github.io/2018-05-10-macquarie-university/
# 1546  https://bio-swc-bne.github.io/2018-06-06-ResbazBris-Python/
# 1547  https://bio-swc-bne.github.io/2018-06-06-ResbazBris-R/
# 1560  https://weaverbel.github.io/2018-06-12-wrds/
# 1591  https://bio-swc-bne.github.io/2018-06-28-uqws/
# 1594  https://piccolomud.github.io/2018-07-03-ResBazPythonIntro/
# 1595  http://daryavanichkina.com/2018-07-03-ResbazSydney/
# 1597  https://mq-software-carpentry.github.io/2018-07-03-resbaz-python-advanced/
# 1598  https://humburg.github.io/2018-07-03-resbaz-sydneyAdvR/
# 1599  https://denubis.github.io/2018-07-03-resbaz2018sql/
# 1609  https://curtinic.github.io/2018-07-16-curtin/
# 1657  https://stapleto.github.io/swc-2018-08-28-qut/
# 1687  https://mq-software-carpentry.github.io/2018-09-18-mq-python/
# 1711  https://fgacenga.github.io/2018-10-02-usq/
# 1718  https://bio-swc-bne.github.io/2018-10-08-GriffithUni-Python/
# 1757  https://denubis.github.io/2018-10-29-MacquarieUniversity/
# 1868  http://vlsci.github.io/datacarpentry_2015-11-23_VLSCI/
#
#         country country3 workshop_type
# 53    Australia  AUS      SWC
# 54    Australia  AUS      SWC
# 117   Australia  AUS      SWC
# 121   Australia  AUS      SWC
# 123   Australia  AUS      SWC
# 132   Australia  AUS      SWC
# 153   Australia  AUS      SWC
# 155   Australia  AUS      SWC
# 158   Australia  AUS      SWC
# 168   Australia  AUS      SWC
# 196   Australia  AUS      SWC
# 228   Australia  AUS      SWC
# 234   Australia  AUS      SWC
# 246   Australia  AUS      SWC
# 264   Australia  AUS      SWC
# 280   Australia  AUS      SWC
# 318   Australia  AUS      SWC
# 319   Australia  AUS      SWC
# 320   Australia  AUS      SWC
# 347   Australia  AUS      SWC
# 367   Australia  AUS      SWC
# 368   Australia  AUS      SWC
# 377   Australia  AUS      SWC
# 392   Australia  AUS      SWC
# 420   Australia  AUS      SWC
# 422   Australia  AUS      SWC
# 423   Australia  AUS      SWC
# 427   Australia  AUS      SWC
# 429   Australia  AUS      SWC
# 434   Australia  AUS      SWC
# 445   Australia  AUS      SWC
# 474   Australia  AUS      SWC
# 480   Australia  AUS      SWC
# 494   Australia  AUS      SWC
# 497   Australia  AUS      SWC
# 498   Australia  AUS      SWC
# 499   Australia  AUS      SWC
# 505   Australia  AUS      DC
# 510   Australia  AUS      SWC
# 531   Australia  AUS      SWC
# 553   Australia  AUS      SWC
# 557   Australia  AUS      SWC
# 560   Australia  AUS      SWC
# 562   Australia  AUS      SWC
# 568   Australia  AUS      SWC
# 569   Australia  AUS      SWC
# 573   Australia  AUS      SWC
# 617   Australia  AUS      SWC
# 618   Australia  AUS      SWC
# 619   Australia  AUS      SWC
# 620   Australia  AUS      SWC
# 622   Australia  AUS      SWC
# 623   Australia  AUS      SWC
# 624   Australia  AUS      SWC
# 675   Australia  AUS      SWC
# 676   Australia  AUS      SWC
# 682   Australia  AUS      SWC
# 684   Australia  AUS      SWC
# 686   Australia  AUS      SWC
# 695   Australia  AUS      SWC
# 698   Australia  AUS      SWC
# 718   Australia  AUS      DC
# 743   Australia  AUS      SWC
# 752   Australia  AUS      SWC
# 771   Australia  AUS      SWC
# 776   Australia  AUS      SWC
# 791   Australia  AUS      SWC
# 794   Australia  AUS      SWC
# 798   Australia  AUS      SWC
# 799   Australia  AUS      SWC
# 801   Australia  AUS      DC
# 809   Australia  AUS      SWC
# 813   Australia  AUS      SWC
# 817   Australia  AUS      DC
# 821   Australia  AUS      SWC
# 854   Australia  AUS      SWC
# 864   Australia  AUS      SWC
# 868   Australia  AUS      SWC
# 869   Australia  AUS      SWC
# 870   Australia  AUS      SWC
# 872   Australia  AUS      SWC
# 882   Australia  AUS      SWC
# 886   Australia  AUS      SWC
# 907   Australia  AUS      DC
# 924   Australia  AUS      SWC
# 934   Australia  AUS      SWC
# 944   Australia  AUS      SWC
# 954   Australia  AUS      SWC
# 986   Australia  AUS      SWC
# 987   Australia  AUS      SWC
# 988   Australia  AUS      SWC
# 996   Australia  AUS      SWC
# 1015  Australia  AUS      SWC
# 1017  Australia  AUS      SWC
# 1030  Australia  AUS      SWC
# 1047  Australia  AUS      DC
# 1052  Australia  AUS      SWC
# 1055  Australia  AUS      SWC
# 1056  Australia  AUS      SWC
# 1086  Australia  AUS      SWC
# 1088  Australia  AUS      SWC
# 1102  Australia  AUS      SWC
# 1107  Australia  AUS      SWC
# 1117  Australia  AUS      DC
# 1139  Australia  AUS      SWC
# 1140  Australia  AUS      SWC
# 1143  Australia  AUS      SWC
# 1148  Australia  AUS      SWC
# 1167  Australia  AUS      SWC
# 1175  Australia  AUS      SWC
# 1176  Australia  AUS      SWC
# 1189  Australia  AUS      SWC
# 1205  Australia  AUS      SWC
# 1210  Australia  AUS      SWC
# 1214  Australia  AUS      SWC
# 1237  Australia  AUS      SWC
# 1239  Australia  AUS      SWC
# 1290  Australia  AUS      SWC
# 1302  Australia  AUS      SWC
# 1317  Australia  AUS      SWC
# 1318  Australia  AUS      SWC
# 1333  Australia  AUS      SWC
# 1375  Australia  AUS      SWC
# 1387  Australia  AUS      DC
# 1390  Australia  AUS      SWC
# 1400  Australia  AUS      DC
# 1401  Australia  AUS      SWC
# 1447  Australia  AUS      SWC
# 1475  Australia  AUS      SWC
# 1489  Australia  AUS      SWC
# 1499  Australia  AUS      SWC
# 1517  Australia  AUS      SWC
# 1546  Australia  AUS      SWC
# 1547  Australia  AUS      SWC
# 1560  Australia  AUS      SWC
# 1591  Australia  AUS      SWC
# 1594  Australia  AUS      SWC
# 1595  Australia  AUS      DC
# 1597  Australia  AUS      SWC
# 1598  Australia  AUS      SWC
# 1599  Australia  AUS      SWC
# 1609  Australia  AUS      SWC
# 1657  Australia  AUS      SWC
# 1687  Australia  AUS      SWC
# 1711  Australia  AUS      SWC
# 1718  Australia  AUS      SWC
# 1757  Australia  AUS      SWC
# 1868  Australia  AUS      DC

# %%
# Count of workshops by Carpentry and by year. This year's data is actual, not projected.

workshops_by_carpentry_year = workshops.groupby([workshops['start_date'].dt.year, 'workshop_type'])['slug'].count().unstack()

# To calculate projections for current year, take number of workshops at same point in last year

# Get the year of the max date in our data set
current_year = max(workshops['start_date'].dt.year)

# Get one year ago based on that
last_year = current_year - 1

# Get the actual date of the latest workshop in our data set
latest_workshop_date = max(workshops['start_date'])

# Get the comparison date one year ago
last_year_comparision_date = max(workshops['start_date']) - datetime.timedelta(days=365)

# January 1 of last year
# last_year_first_day = datetime.date(last_year, 1, 1)
last_year_first_day = pd.Timestamp(last_year, 1, 1)

# Count how many workshops happened between Jan 1 of last year and the comparison date one year ago
last_year_workshops_to_comp_date = workshops[(workshops.start_date >= last_year_first_day) & (workshops.start_date <= last_year_comparision_date)]

# Count how many workshops happened total last year
count_last_year_workshops = len(workshops[workshops['start_date'].dt.year == last_year])

# Count YTD workshops this year
count_this_year_workshops = len(workshops[workshops['start_date'].dt.year == current_year])

# Last year's workshops by Carpentry by year through the comparison date
last_year_to_comp_date_by_carpentry = last_year_workshops_to_comp_date.groupby([last_year_workshops_to_comp_date['start_date'].dt.year, 'workshop_type'])['slug'].count().unstack()

# Last year's workshops by Carpentry by year total
last_year_total_by_carpentry = workshops_by_carpentry_year.loc[[last_year]]

# This year's workshops by Carpentry by year to date
this_year_to_date_by_carpentry = workshops_by_carpentry_year.loc[[current_year]]

# Proportion of workshops by Carpentry by year that had occured by the comparison date
proportion = last_year_to_comp_date_by_carpentry/last_year_total_by_carpentry

# Rename the rows so we can run calculations on them
this_year_to_date_by_carpentry.rename({current_year:1}, inplace=True)
proportion.rename({last_year:1}, inplace=True)

# Assuming current year will progress at same proportionate rate
# calculate the projected number of workshops for the current year
current_year_projected = this_year_to_date_by_carpentry.iloc[[0]]/proportion.iloc[[0]]

# Rename the row for the current year projections
current_year_projected.rename({1:current_year}, inplace=True)

# In the workshops by carpentry year dataframe, replace the actual current year data
# with projected current year data
workshops_by_carpentry_year.loc[[current_year]] = current_year_projected.loc[[current_year]]

# Replace the NaNs with 0 and convert floats to ints
workshops_by_carpentry_year.fillna(0, inplace=True)
workshops_by_carpentry_year = workshops_by_carpentry_year.round(0)
workshops_by_carpentry_year = workshops_by_carpentry_year.astype(int)


workshops_by_carpentry_year.index.name = 'Year'
workshops_by_carpentry_year.columns.name = "Workshop Type"

current_year_workshops = dict((workshops_by_carpentry_year.loc[current_year]))

# %% [markdown]
# ### {{ chosen_country }}  Based Workshops by Carpentry by year
#
# * Map should be a close up map

# %%
fig = plt.figure(figsize=(12, 6)) # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes

width = .5 # Set width of bar
title = "Carpentries workshops count by year"

# Set axes labels and legend
ax.set_xlabel("Year")
ax.set_ylabel("Workshop Count")
# ax.legend(title="Workshop Type", fontsize=12)

ax.title.set_size(18)
ax.xaxis.label.set_size(18)
ax.yaxis.label.set_size(18)
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize=14, rotation=0)

# Plot chart
workshops_by_carpentry_year.plot(y = ["DC", "SWC"], kind='bar', ax=ax, width=width,  title=title, stacked=True,)

leg = ax.legend(fontsize=12)
leg.set_title(title="Workshop Type", prop={'size':14,})


# Customize the gridlines
ax.grid(linestyle='-', linewidth='0.25', color='gray')

# Create a new dataframe that has just the total number of workshops by year
totals = workshops_by_carpentry_year['DC'] + workshops_by_carpentry_year['SWC']
years = list(totals.index)


# Figure out what the xmarks values are (xtick values; they are not year like you'd think)
# Add them to an empty list
# The list will be double what's expected as it goes through all the stacked values
xmarks = []
for p in ax.patches:
#     print("X: ", p.get_x())
#     print("Y: ", p.get_height())
    xmarks.append(p.get_x())


# Make an empty list to be populated with a tuple for each stack
# Go through the length of the totals series
# Add to the empty list a tuple: (position in totals df, position in xmarks list)
t = []

for y in range(len(totals)):
    t.append((list(totals)[y], xmarks[y]))


# Annotate the stacked bar chart with 
# (annotation text, position of text)
for p in t:
    ax.annotate(str(p[0]), (p[1] + .08, p[0] + 5), fontsize=14)

# Don't allow the axis to be on top of your data
ax.set_axisbelow(True)    

ax.set_ylim(0,max(totals) + 50)

    
# Display the plot   
plt.show()


# See
# https://stackoverflow.com/questions/40783669/stacked-bar-plot-by-group-count-on-pandas-python

# %%
workshops_with_location = workshops[workshops.latitude.notnull()]
workshops_with_location = workshops_with_location[workshops_with_location.longitude.notnull()]

# For more info see 
# https://www.earthdatascience.org/courses/earth-analytics-python/spatial-data-vector-shapefiles/intro-to-coordinate-reference-systems-python/
# https://github.com/geopandas/geopandas/issues/245

# Make simple df with just the latlon columns
latlon = workshops_with_location[['longitude', 'latitude']]

# world map with latlong projections
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')).to_crs(epsg=4326) #.to_crs('+proj=robin') # world map

# Turn latlon into list of shapely points
q  = [Point(xy) for xy in latlon.values]

# Create geodataframe using these points
q = gpd.GeoDataFrame(q, columns = ['geometry'])

# q.head()
# This is a "naive" object; need to explicitly set the crs to 4326 (latlon)
q.crs = {'init': 'epsg:4326', 'no_defs': True}

# Now translate both latlons to robinson projection - a bit "rounder"
# world = world.to_crs('+proj=robin')
q = q.to_crs('+proj=robin')


fig, ax = plt.subplots(figsize=(15, 8))

# Not sure what alpha means
bbox_robinson.plot(ax=ax, alpha=1, color='whitesmoke', edgecolor='dimgray')


world_robinson.plot(color='darkgrey', ax=ax,)

q.plot(ax=ax, color='royalblue', marker='o', markersize=10)

# ax.axis('off')

# facecolor will not work if ax.axis is off
# ax.patch.set_facecolor('whitesmoke')
# # Drop x & y axis ticks
plt.xticks([], [])
plt.yticks([], [])

ax.set_title("Carpentries workshops, 2012-2018")
ax.title.set_size(18)



# Make the axes invisible by making them the same color as the background
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white') 
ax.spines['right'].set_color('white')
ax.spines['left'].set_color('white')



plt.show()

# %%
workshops_current_year = workshops[workshops['start_date'].dt.year == current_year].copy()
workshops_current_year.attendance.fillna(0, inplace=True)
current_year_no_attendance = workshops_current_year[workshops_current_year.attendance ==0].copy()
percent_missing_attendance =  len(current_year_no_attendance)/len(workshops_current_year) * 100
percent_missing_attendance = int(percent_missing_attendance)

# percent_missing_attendance

# %% [markdown]
# ## Learners and Attendance
#
# In {{ current_year }}, {{ percent_missing_attendance }}% of workshops do not have attendance recorded.  Below are all workshops missing attendance.

# %%
display(current_year_no_attendance)
# Out:
# Empty DataFrame
# Columns: [slug, start_date, attendance, host_name, country2, latitude, longitude, url, country, country3, workshop_type]
# Index: []

# %%
# Learners by year


# Actual data for learners by year through 2018
# Projections for 2018 are calculated below

learners_by_year = workshops.groupby([workshops['start_date'].dt.year, 'workshop_type'])['attendance'].sum().unstack()
learners_by_year = learners_by_year.fillna(0)
# learners_by_year.rename(columns={'slug': 'learner_count'}, inplace=True)
# # workshops_by_country_year['total'] = workshops_by_country_year.sum(axis=1)
# learners_by_year.columns.names = ['Year']
# # workshops_by_country_year[current_year] = workshops_by_country_year[current_year]/.75
learners_by_year = learners_by_year.astype(int)

# # display(workshops_by_country_year)

# ##############

# Last year's attendance by year through the comparison date
# # Take *all* of last year's workshop by the com date and group them by Carpentry type
last_year_to_comp_date_attendance = last_year_workshops_to_comp_date.groupby([workshops['start_date'].dt.year, 'workshop_type'])['attendance'].sum().unstack()
# # # current_year_projected.rename({1:current_year}, inplace=True)
# last_year_to_comp_date_by_country.rename(columns={'slug':last_year}, inplace=True)

# Last year's workshops attendance by year total
# # Get just the last_year column from the workshops_by_country_year df
learners_last_year = learners_by_year.loc[[last_year]]

# Rename the rows so we can run calculations on them
learners_by_year.rename({current_year:1}, inplace=True)

x = last_year_to_comp_date_attendance/learners_last_year


x.rename({last_year:1}, inplace=True)

# learners_by_year.loc[[2018]]/x.loc[[2017]]
# display(x.loc[[2017]])
# display(learners_by_year.loc[[2018]])
# learners_by_year.loc[[2018]]/x.loc[[2017]]
learners_by_year.loc[[1]] = learners_by_year.loc[[1]]/x
learners_by_year.rename({1:current_year}, inplace=True)
learners_by_year = learners_by_year.round(0)
learners_by_year = learners_by_year.astype(int)


learners_by_year.index.name = 'Year'
learners_by_year.columns.name = "Workshop Type"

# %%
fig = plt.figure(figsize=(12, 6)) # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes

width = .5 # Set width of bar
title = "Carpentries attendance by year"

# Plot chart
# Having position=1 as an argument will make the bars not be centered on the x ticks
learners_by_year.plot(y = ["DC", "SWC"], kind='bar', ax=ax, width=width, title=title, stacked=True,)

# Set axes labels and legend
ax.set_xlabel("Year")
ax.set_ylabel("Workshop Count")
# ax.legend(title="Workshop Type", fontsize=12)
leg = ax.legend(fontsize=12)
leg.set_title(title="Workshop Type", prop={'size':14,})
ax.title.set_size(18)
ax.xaxis.label.set_size(18)
ax.yaxis.label.set_size(18)
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize=14, rotation=0)



# Customize the gridlines
ax.grid(linestyle='-', linewidth='0.25', color='gray')

# Create a new dataframe that has just the total number of workshops by year
totals = learners_by_year['DC'] + learners_by_year['SWC']
years = list(totals.index)


# Figure out what the xmarks values are (xtick values; they are not year like you'd think)
# Add them to an empty list
# The list will be double what's expected as it goes through all the stacked values
xmarks = []
for p in ax.patches:
#     print("X: ", p.get_x())
#     print("Y: ", p.get_height())
    xmarks.append(p.get_x())


# Make an empty list to be populated with a tuple for each stack
# Go through the length of the totals series
# Add to the empty list a tuple: (position in totals df, position in xmarks list)
t = []

for y in range(len(totals)):
    t.append((list(totals)[y], xmarks[y]))


# Annotate the stacked bar chart with 
# (annotation text, position of text)
for p in t:
    ax.annotate(str(p[0]), (p[1] + .08, p[0] + 100), fontsize=14)

# Don't allow the axis to be on top of your data
ax.set_axisbelow(True)    

ax.set_ylim(0,max(totals) + 500)

    
# Display the plot   
plt.show()


# See
# https://stackoverflow.com/questions/40783669/stacked-bar-plot-by-group-count-on-pandas-python

# %% [markdown]
# ### All workshops by Carpentry by Year

# %%
workshops_by_carpentry_year
# Out:
# Workshop Type  DC  SWC
# Year
# 2013           0   6
# 2014           0   10
# 2015           2   30
# 2016           4   37
# 2017           2   32
# 2018           3   26

# %% [markdown]
# ### All workshops

# %%
workshops
# Out:
#                                               slug start_date  attendance  \
# 53    2013-02-07-macquarie                         2013-02-07  38.0
# 54    2013-02-14-amos                              2013-02-14  68.0
# 117   2013-09-24-acpfgA                            2013-09-24  20.0
# 121   2013-10-01-acpfgM                            2013-10-01  27.0
# 123   2013-10-09-canberra                          2013-10-09  35.0
# 132   2013-11-25-unimelb                           2013-11-25  36.0
# 153   2014-02-10-hobart                            2014-02-10  37.0
# 155   2014-02-13-UNSW                              2014-02-13  38.0
# 158   2014-02-18-UTS                               2014-02-18  29.0
# 168   2014-03-18-combine                           2014-03-18  42.0
# 196   2014-06-02-monash                            2014-06-02  36.0
# 228   2014-07-30-pyconaus                          2014-07-30  40.0
# 234   2014-08-18-unimelb                           2014-08-18  45.0
# 246   2014-09-15-unimelb                           2014-09-15  44.0
# 264   2014-10-31-USyd                              2014-10-31  27.0
# 280   2014-12-08-combine-r                         2014-12-08  42.0
# 318   2015-02-16-resbaz-matlab                     2015-02-16  17.0
# 319   2015-02-16-resbaz-python                     2015-02-16  47.0
# 320   2015-02-16-resbaz-r                          2015-02-16  43.0
# 347   2015-04-08-SWC-UniMelb-Biosciences           2015-04-08  42.0
# 367   2015-05-04-matlab                            2015-05-04  17.0
# 368   2015-05-04-swinpython                        2015-05-04  28.0
# 377   2015-05-25-unimelb                           2015-05-25  24.0
# 392   2015-06-08-matlab                            2015-06-08  22.0
# 420   2015-06-29-qaeco-unimelb                     2015-06-29  21.0
# 422   2015-07-02-UQ                                2015-07-02  39.0
# 423   2015-07-02-monash                            2015-07-02  35.0
# 427   2015-07-13-amos                              2015-07-13  24.0
# 429   2015-07-13-unimelb                           2015-07-13  22.0
# 434   2015-07-20-perth                             2015-07-20  19.0
# 445   2015-08-05-UWS                               2015-08-05  15.0
# 474   2015-09-10-SWC-ANU                           2015-09-10  41.0
# 480   2015-09-17-WSU                               2015-09-17  17.0
# 494   2015-09-28-UQ                                2015-09-28  38.0
# 497   2015-09-28-unimelb-r-psychology              2015-09-28  23.0
# 498   2015-10-01-CPCEMCR                           2015-10-01  20.0
# 499   2015-10-01-JamesCookUni                      2015-10-01  23.0
# 505   2015-10-07-R-Data-Sydney                     2015-10-07  19.0
# 510   2015-10-17-IEEE-Python                       2015-10-17  27.0
# 531   2015-11-05-CSU                               2015-11-05  5.0
# 553   2015-11-23-ccrc                              2015-11-22  30.0
# 557   2015-11-26-adelaide-python                   2015-11-26  42.0
# 560   2015-12-01-uow                               2015-12-01  14.0
# 562   2015-12-07-Python-for-Science                2015-12-07  38.0
# 568   2015-12-08-USYD                              2015-12-08  22.0
# 569   2015-12-09-TRI                               2015-12-09  24.0
# 573   2015-12-14-Python-for-Researchers            2015-12-14  31.0
# 617   2016-02-01-BrisbaneResBaz-Python             2016-02-01  32.0
# 618   2016-02-01-BrisbaneResBaz-R                  2016-02-01  34.0
# 619   2016-02-01-ResBaz                            2016-02-01  22.0
# 620   2016-02-01-ResBaz-Sydney-RBeginner           2016-02-01  15.0
# 622   2016-02-01-perth                             2016-02-01  78.0
# 623   2016-02-01-python-resbaz-2016                2016-02-01 NaN
# 624   2016-02-01-rezbazsydneypython                2016-02-01  23.0
# 675   2016-03-30-Python-for-Positive-Psychology    2016-03-29  58.0
# 676   2016-03-31-UNSW                              2016-03-31  27.0
# 682   2016-04-06-UON                               2016-04-06  22.0
# 684   2016-04-11-dsiti                             2016-04-11  16.0
# 686   2016-04-12-UTS                               2016-04-12  21.0
# 695   2016-04-18-USYD                              2016-04-18  18.0
# 698   2016-04-19-GriffithUni                       2016-04-19  22.0
# 718   2016-05-12-CharlesDarwinUni                  2016-05-12 NaN
# 743   2016-05-31-CQU-R                             2016-05-31  11.0
# 752   2016-06-06-GriffithUni-Python                2016-06-06 NaN
# 771   2016-06-16-VetSciUnimelb                     2016-06-16  38.0
# 776   2016-06-21-LTU                               2016-06-21  10.0
# 791   2016-07-11-UNSW                              2016-07-11  26.0
# 794   2016-07-11-bne-R                             2016-07-11  1.0
# 798   2016-07-18-curtin                            2016-07-18 NaN
# 799   2016-07-18-usq                               2016-07-18 NaN
# 801   2016-07-20-UTS_Library_Data_Carpentry        2016-07-12  40.0
# 809   2016-08-02-dsiti                             2016-08-02 NaN
# 813   2016-08-05-hobart                            2016-08-26  45.0
# 817   2016-08-10-Pre-Pycon_Data_Carpentry_Workshop 2016-08-10  33.0
# 821   2016-08-16-WSU                               2016-08-16 NaN
# 854   2016-09-14-GriffithUni-Python                2016-09-14 NaN
# 864   2016-09-21-UON                               2016-09-21 NaN
# 868   2016-09-26-usq                               2016-09-26 NaN
# 869   2016-09-27-SoftwareCarpentry-tsv             2016-09-27 NaN
# 870   2016-09-27-UNSW                              2016-09-27 NaN
# 872   2016-09-28-GriffithUni-R                     2016-09-28 NaN
# 882   2016-10-05-LTU                               2016-10-05 NaN
# 886   2016-10-06-QBI                               2016-10-06 NaN
# 907   2016-10-25-uwa                               2016-10-25  35.0
# 924   2016-11-07-Curtin                            2016-11-07  26.0
# 934   2016-11-14-unimelb                           2016-11-14  9.0
# 944   2016-11-29-qut                               2016-11-29  31.0
# 954   2016-12-12-Deakin                            2016-12-12 NaN
# 986   2017-01-30-NeuRA-Python                      2017-01-30  23.0
# 987   2017-01-31-resbaztas-python                  2017-01-31  40.0
# 988   2017-01-31-resbaztas-r                       2017-01-31  50.0
# 996   2017-02-05-amos                              2017-02-05  17.0
# 1015  2017-02-27-UTS                               2017-02-27  25.0
# 1017  2017-03-02-SoftwareCarpentry-tsv             2017-03-02 NaN
# 1030  2017-03-16-SoftwareCarpentryPy-TSV           2017-03-16  24.0
# 1047  2017-04-06-DataCarpentry-Genomics-TSV        2017-04-06 NaN
# 1052  2017-04-10-GriffithUni-Python                2017-04-10  24.0
# 1055  2017-04-12-GriffithUni-Git                   2017-04-12  32.0
# 1056  2017-04-20-SWC-Melbourne                     2017-04-20  25.0
# 1086  2017-05-17-qbi                               2017-05-17  17.0
# 1088  2017-05-18-R-Macquarie                       2017-05-18  18.0
# 1102  2017-05-29-GriffithUni-R                     2017-05-29  27.0
# 1107  2017-06-06-Curtin                            2017-06-06  23.0
# 1117  2017-06-15-uow                               2017-06-15  19.0
# 1139  2017-07-03-ResBaz-Python                     2017-07-03 NaN
# 1140  2017-07-03-ResBaz-R                          2017-07-03 NaN
# 1143  2017-07-03-sydney-resbaz-r-novice            2017-07-03  25.0
# 1148  2017-07-10-uqws                              2017-07-10  31.0
# 1167  2017-07-27-hobart                            2017-07-27  45.0
# 1175  2017-08-01-resbazp                           2017-02-08  37.0
# 1176  2017-08-01-resbazr                           2017-02-08  38.0
# 1189  2017-08-10-qbi                               2017-08-10  9.0
# 1205  2017-08-21-GriffithUni-R                     2017-08-21  22.0
# 1210  2017-08-28-curtin                            2017-08-28  28.0
# 1214  2017-08-31-MacquarieUniversity               2017-08-31  16.0
# 1237  2017-09-25-usq                               2017-09-25 NaN
# 1239  2017-09-26-MacquarieUniversity               2017-09-26  16.0
# 1290  2017-10-31-qut                               2017-10-31  34.0
# 1302  2017-11-07-curtin                            2017-11-07  23.0
# 1317  2017-11-23-GriffithUni-Python                2017-11-23  24.0
# 1318  2017-11-27-USyd-Python                       2017-11-27  12.0
# 1333  2017-12-12-MQU-R                             2017-12-12  34.0
# 1375  2018-01-23-uwa                               2018-01-23  54.0
# 1387  2018-02-04-amos-icshmo                       2018-02-04  40.0
# 1390  2018-02-07-GriffithUni-Python                2018-02-07  13.0
# 1400  2018-02-20-MQU-DC                            2018-02-20  39.0
# 1401  2018-02-20-qut                               2018-02-20  12.0
# 1447  2018-03-19-curtin                            2018-03-19  28.0
# 1475  2018-04-11-GriffithUni-R                     2018-04-11  22.0
# 1489  2018-04-23-curtin                            2018-04-23  39.0
# 1499  2018-04-26-WEHI                              2018-04-26  27.0
# 1517  2018-05-10-macquarie-university              2018-05-10  28.0
# 1546  2018-06-06-ResbazBris-Python                 2018-06-06  30.0
# 1547  2018-06-06-ResbazBris-R                      2018-06-06  30.0
# 1560  2018-06-12-wrds                              2018-06-12  15.0
# 1591  2018-06-28-uqws                              2018-06-28  32.0
# 1594  2018-07-03-ResBazPythonIntro                 2018-07-03  48.0
# 1595  2018-07-03-ResbazSydney                      2018-07-03  62.0
# 1597  2018-07-03-resbaz-python-advanced            2018-07-03  37.0
# 1598  2018-07-03-resbaz-sydneyAdvR                 2018-07-03  37.0
# 1599  2018-07-03-resbaz2018sql                     2018-07-03  27.0
# 1609  2018-07-16-curtin                            2018-07-16  30.0
# 1657  2018-08-28-qut                               2018-08-28  27.0
# 1687  2018-09-18-mq-python                         2018-09-18  35.0
# 1711  2018-10-02-usq                               2018-10-02  33.0
# 1718  2018-10-08-GriffithUni-Python                2018-10-08  25.0
# 1757  2018-10-29-MacquarieUniversity               2018-10-29  29.0
# 1868  datacarpentry_2015-11-23_VLSCI               2015-11-23  18.0
#
#                                                          host_name country2  \
# 53    Macquarie University                                          AU
# 54    AMOS Conference (Melbourne)                                   AU
# 117   Australian Centre for Plant Functional Genomics               AU
# 121   Australian Centre for Plant Functional Genomics               AU
# 123   Australian National University                                AU
# 132   University of Melbourne                                       AU
# 153   AMOS Conference (Melbourne)                                   AU
# 155   University of New South Wales                                 AU
# 158   University of Technology Sydney                               AU
# 168   University of Melbourne                                       AU
# 196   Monash University                                             AU
# 228   University of Queensland                                      AU
# 234   University of Melbourne                                       AU
# 246   University of Melbourne                                       AU
# 264   University of Sydney                                          AU
# 280   University of Melbourne                                       AU
# 318   University of Melbourne                                       AU
# 319   University of Melbourne                                       AU
# 320   University of Melbourne                                       AU
# 347   University of Melbourne                                       AU
# 367   University of Melbourne                                       AU
# 368   Swinburne University of Technology                            AU
# 377   University of Melbourne                                       AU
# 392   University of Melbourne                                       AU
# 420   University of Melbourne                                       AU
# 422   University of Queensland                                      AU
# 423   Monash University                                             AU
# 427   University of Queensland                                      AU
# 429   University of Melbourne                                       AU
# 434   Curtin University                                             AU
# 445   Intersect Australia                                           AU
# 474   Australian National University                                AU
# 480   Intersect Australia                                           AU
# 494   University of Queensland                                      AU
# 497   University of Melbourne                                       AU
# 498   University of Sydney                                          AU
# 499   James Cook University                                         AU
# 505   University of Sydney                                          AU
# 510   University of Melbourne                                       AU
# 531   Charles Sturt University                                      AU
# 553   University of New South Wales                                 AU
# 557   University of Adelaide                                        AU
# 560   University of Wollongong                                      AU
# 562   University of Melbourne                                       AU
# 568   University of Sydney                                          AU
# 569   Translational Research Institute                              AU
# 573   University of Melbourne                                       AU
# 617   Queensland University of Technology                           AU
# 618   Queensland University of Technology                           AU
# 619   University of Sydney                                          AU
# 620   University of Sydney                                          AU
# 622   Curtin University                                             AU
# 623   University of Melbourne                                       AU
# 624   University of Sydney                                          AU
# 675   University of Melbourne                                       AU
# 676   Intersect Australia                                           AU
# 682   Intersect Australia                                           AU
# 684   Department of Science, Information Technology and Innovation  AU
# 686   Intersect Australia                                           AU
# 695   Intersect Australia                                           AU
# 698   Griffith University                                           AU
# 718   Charles Darwin University                                     AU
# 743   CQUniversity                                                  AU
# 752   Griffith University                                           AU
# 771   COMBINE                                                       AU
# 776   Intersect Australia                                           AU
# 791   Intersect Australia                                           AU
# 794   University of Queensland                                      AU
# 798   Curtin University                                             AU
# 799   University of Southern Queensland                             AU
# 801   University of Melbourne                                       AU
# 809   Department of Science, Information Technology and Innovation  AU
# 813   Data Science Hobart                                           AU
# 817   VLSCI                                                         AU
# 821   Intersect Australia                                           AU
# 854   Griffith University                                           AU
# 864   Intersect Australia                                           AU
# 868   University of Southern Queensland                             AU
# 869   James Cook University                                         AU
# 870   Intersect Australia                                           AU
# 872   Griffith University                                           AU
# 882   Intersect Australia                                           AU
# 886   University of Queensland                                      AU
# 907   University of Western Australia                               AU
# 924   Curtin University                                             AU
# 934   ARC Centre of Excellence for Climate System Science           AU
# 944   Queensland University of Technology                           AU
# 954   Intersect Australia                                           AU
# 986   Neuroscience Research Australia                               AU
# 987   Data Science Hobart                                           AU
# 988   Data Science Hobart                                           AU
# 996   Australian Meteorological and Oceanographic Society           AU
# 1015  University of Technology Sydney                               AU
# 1017  James Cook University                                         AU
# 1030  James Cook University                                         AU
# 1047  James Cook University                                         AU
# 1052  Griffith University                                           AU
# 1055  Griffith University                                           AU
# 1056  COMBINE                                                       AU
# 1086  University of Queensland                                      AU
# 1088  Macquarie University                                          AU
# 1102  Griffith University                                           AU
# 1107  Curtin University                                             AU
# 1117  University of Wollongong                                      AU
# 1139  Intersect Australia                                           AU
# 1140  Intersect Australia                                           AU
# 1143  Macquarie University                                          AU
# 1148  University of Queensland                                      AU
# 1167  Data Science Hobart                                           AU
# 1175  University of Queensland                                      AU
# 1176  University of Queensland                                      AU
# 1189  University of Queensland                                      AU
# 1205  Griffith University                                           AU
# 1210  Curtin University                                             AU
# 1214  Macquarie University                                          AU
# 1237  University of Southern Queensland                             AU
# 1239  Macquarie University                                          AU
# 1290  Queensland University of Technology                           AU
# 1302  Curtin University                                             AU
# 1317  Griffith University                                           AU
# 1318  University of Sydney                                          AU
# 1333  Macquarie University                                          AU
# 1375  Curtin University                                             AU
# 1387  Australian Meteorological and Oceanographic Society           AU
# 1390  Griffith University                                           AU
# 1400  Macquarie University                                          AU
# 1401  Queensland University of Technology                           AU
# 1447  Curtin University                                             AU
# 1475  Griffith University                                           AU
# 1489  Curtin University                                             AU
# 1499  COMBINE                                                       AU
# 1517  Macquarie University                                          AU
# 1546  Griffith University                                           AU
# 1547  Griffith University                                           AU
# 1560  University of Queensland                                      AU
# 1591  University of Queensland                                      AU
# 1594  Macquarie University                                          AU
# 1595  Macquarie University                                          AU
# 1597  Macquarie University                                          AU
# 1598  Macquarie University                                          AU
# 1599  Macquarie University                                          AU
# 1609  Curtin University                                             AU
# 1657  Queensland University of Technology                           AU
# 1687  Macquarie University                                          AU
# 1711  Queensland Cyber Infrastructure Foundation                    AU
# 1718  Griffith University                                           AU
# 1757  Macquarie University                                          AU
# 1868  VLSCI                                                         AU
#
#        latitude   longitude  \
# 53   -33.773636  151.112005
# 54   -37.825328  144.951621
# 117  -34.919159  138.604140
# 121  -37.908300  145.138000
# 123  -35.277700  149.118530
# 132  -37.796300  144.961400
# 153  -42.880600  147.325000
# 155  -33.917410  151.231307
# 158  -33.883898  151.201013
# 168  -37.796300  144.961400
# 196  -37.915211  145.134682
# 228  -27.501420  153.015150
# 234  -37.796300  144.961400
# 246  -37.796300  144.961400
# 264  -33.887526  151.190262
# 280  -37.800138  144.959285
# 318  -37.799243  144.964422
# 319  -37.799243  144.964422
# 320  -37.799243  144.964422
# 347  -37.800265  144.959805
# 367  -37.799243  144.964422
# 368  -37.821771  145.038931
# 377  -37.792910  144.961174
# 392  -37.800483  144.965807
# 420  -37.800091  144.959021
# 422  -27.501425  153.014930
# 423  -37.912270  145.132756
# 427  -27.497257  153.014473
# 429  -37.797738  144.960107
# 434  -31.994450  115.885636
# 445  -33.810273  151.024438
# 474  -35.277700  149.118527
# 480  -33.810273  151.024438
# 494  -27.501425  153.014930
# 497  -37.800091  144.959021
# 498  -33.887261  151.183828
# 499  -19.329376  146.760334
# 505  -33.887674  151.190280
# 510  -37.792910  144.961174
# 531  -35.064656  147.359956
# 553  -33.917763  151.234260
# 557  -34.919136  138.604870
# 560  -34.405678  150.881178
# 562  -37.797915  144.959933
# 568  -33.887037  151.180855
# 569  -27.498869  153.031914
# 573  -37.792910  144.961174
# 617  -27.476664  153.027965
# 618  -27.476664  153.027965
# 619  -33.888009  151.186698
# 620  -33.887371  151.190656
# 622  -32.066462  115.830142
# 623  -37.797915  144.959933
# 624  -33.887348  151.190090
# 675  -37.803975  144.960809
# 676  -33.918488  151.227858
# 682  -32.893143  151.698135
# 684  -27.494863  153.028149
# 686  -33.880858  151.201299
# 695  -33.887362  151.188741
# 698  -27.552079  153.054078
# 718  -12.372200  130.868900
# 743  -23.324108  150.519452
# 752  -27.962224  153.381897
# 771  -37.797664  144.953251
# 776  -37.720935  145.048445
# 791  -33.918488  151.227858
# 794  -27.501425  153.014930
# 798  -32.007532  115.894223
# 799  -27.606578  151.935113
# 801  -33.880842  151.202238
# 809  -27.500077  153.014352
# 813  -42.886048  147.335837
# 817  -37.800146  144.964346
# 821  -33.811304  151.024265
# 854  -27.552941  153.052425
# 864  -32.892772  151.704177
# 868  -27.606578  151.935113
# 869  -19.329383  146.759118
# 870  -33.918488  151.227858
# 872  -27.552941  153.052425
# 882  -36.112302  146.850954
# 886  -27.499389  153.011573
# 907  -31.979177  115.817742
# 924  -32.007532  115.894223
# 934  -37.797168  144.965215
# 944  -27.477586  153.027958
# 954  -38.197907  144.298132
# 986  -33.868820  151.209296
# 987  -42.886048  147.335837
# 988  -42.886048  147.335837
# 996  -35.277682  149.115448
# 1015 -33.883997  151.199156
# 1017 -19.329383  146.759118
# 1030 -19.329383  146.759118
# 1047 -19.260262  146.815951
# 1052 -27.962224  153.381897
# 1055 -27.552941  153.052425
# 1056 -37.796897  144.957442
# 1086 -27.499542  153.011805
# 1088 -33.774238  151.118633
# 1102 -27.552941  153.052425
# 1107 -32.007969  115.892742
# 1117 -34.405710  150.881288
# 1139 -33.880954  151.201288
# 1140 -33.880954  151.201288
# 1143 -33.880910  151.199099
# 1148 -27.501425  153.014930
# 1167 -42.886048  147.335837
# 1175 -27.499480  153.013104
# 1176 -27.499480  153.013104
# 1189 -27.499542  153.011805
# 1205 -27.552941  153.052425
# 1210 -32.007969  115.892742
# 1214 -33.774675  151.113344
# 1237 -27.606578  151.935113
# 1239 -33.774675  151.113344
# 1290 -27.477356  153.028423
# 1302 -32.006963  115.894348
# 1317 -27.962224  153.381897
# 1318 -33.888226  151.188702
# 1333 -33.774693  151.112323
# 1375 -31.985918  115.820776
# 1387 -33.917729  151.234230
# 1390 -27.962224  153.381897
# 1400 -33.775015  151.112545
# 1401 -27.456061  153.013368
# 1447 -32.006195  115.894418
# 1475 -27.552941  153.052425
# 1489 -32.006195  115.894418
# 1499 -37.796897  144.957442
# 1517 -33.774715  151.113321
# 1546 -27.482034  153.024804
# 1547 -27.482034  153.024804
# 1560 -27.515301  152.966883
# 1591 -27.501479  153.012728
# 1594 -33.773824  151.112650
# 1595 -33.775541  151.112154
# 1597 -33.775119  151.114699
# 1598 -33.773949  151.114946
# 1599 -33.775541  151.114343
# 1609 -32.006919  115.892092
# 1657 -27.477340  153.028414
# 1687 -33.775082  151.113010
# 1711 -27.684010  152.907227
# 1718 -27.960345  153.378868
# 1757 -33.774804  151.113281
# 1868 -37.800189  144.964362
#
#                                                                                 url  \
# 53    https://swcarpentry.github.io/2013-02-07-macquarie/
# 54    https://swcarpentry.github.io/2013-02-14-amos/
# 117   https://swcarpentry.github.io/2013-09-24-acpfgA/
# 121   https://swcarpentry.github.io/2013-10-01-acpfgM/
# 123   https://swcarpentry.github.io/2013-10-09-canberra/
# 132   https://damienirving.github.io/2013-11-25-unimelb/
# 153   https://damienirving.github.io/2014-02-10-hobart/
# 155   https://nicercode.github.io/2014-02-13-UNSW/
# 158   https://nicercode.github.io/2014-02-18-UTS/
# 168   https://resbaz.github.io/2014-03-18-combine/
# 196   https://badger-d.github.io/2014-06-02-monash/
# 228   https://philippbayer.github.io/2014-07-30-pyconaus/
# 234   https://resbaz.github.io/2014-08-18-unimelb/
# 246   https://resbaz.github.io/2014-09-15-unimelb/
# 264   https://dbarneche.github.io/2014-10-31-USyd/
# 280   https://resbaz.github.io/2014-12-08-combine-r/
# 318   https://resbaz.github.io/2015-02-16-resbaz-matlab/
# 319   https://resbaz.github.io/2015-02-16-resbaz-python/
# 320   https://resbaz.github.io/2015-02-16-resbaz-r/
# 347   https://COMBINE-Australia.github.io/2015-04-08-SWC-UniMelb-Biosciences/
# 367   https://resbaz.github.io/2015-05-04-matlab/
# 368   https://drarnakarick.github.io/2015-05-04-swinpython/
# 377   https://resbaz.github.io/2015-05-25-unimelb/
# 392   https://resbaz.github.io/2015-06-08-matlab/
# 420   https://resbaz.github.io/2015-06-29-qaeco-unimelb/
# 422   https://bio-swc-bne.github.io/2015-07-02-UQ/
# 423   https://MonashBioinformaticsPlatform.github.io/2015-07-02-monash/
# 427   https://damienirving.github.io/2015-07-13-amos/
# 429   https://resbaz.github.io/2015-07-13-unimelb/
# 434   https://arohl.github.io/2015-07-20-perth/
# 445   https://intersectaustralia.github.io/2015-08-05-UWS/
# 474   https://combine-australia.github.io/2015-09-10-SWC-ANU/
# 480   https://IntersectAustralia.github.io/2015-09-17-WSU/
# 494   https://bio-swc-bne.github.io/2015-09-28-UQ/
# 497   https://resbaz.github.io/2015-09-28-unimelb-r-psychology/
# 498   https://fpheld.github.io/2015-10-01-CPCEMCR/
# 499   https://jcu-eresearch.github.io/2015-10-01-JamesCookUni/
# 505   https://combine-australia.github.io/2015-10-07-R-Data-Sydney/
# 510   https://resbaz.github.io/2015-10-17-IEEE-Python/
# 531   https://intersectaustralia.github.io/2015-11-05-CSU/
# 553   https://nicjhan.github.io/2015-11-23-ccrc/
# 557   http://COMBINE-Australia.github.io/2015-11-26-adelaide-python
# 560   https://benmarwick.github.io/2015-12-01-uow/
# 562   https://resbaz.github.io/2015-12-07-Python-for-Science/
# 568   http://intersectaustralia.github.io/2015-12-08-USYD/
# 569   https://bio-swc-bne.github.io/2015-12-09-TRI/
# 573   https://resbaz.github.io/2015-12-14-Python-for-Researchers/
# 617   http://bio-swc-bne.github.io/2016-02-01-BrisbaneResBaz-Python/
# 618   http://bio-swc-bne.github.io/2016-02-01-BrisbaneResBaz-R/
# 619   http://nicercode.github.io/2016-02-01-ResBaz/
# 620   http://fpheld.github.io/2016-02-01-ResBaz-Sydney-RBeginner/
# 622   http://raffademichelis.github.io/2016-02-01-perth/
# 623   http://resbaz.github.io/python-resbaz-2016/
# 624   http://daryavanichkina.com/2016-02-01-rezbazsydneypython/
# 675   http://alistairwalsh.github.io/2016-03-30-Python-for-Positive-Psychology/
# 676   http://intersectaustralia.github.io/2016-03-31-UNSW/
# 682   http://intersectaustralia.github.io/2016-04-06-UON/
# 684   https://bio-swc-bne.github.io/2016-04-11-dsiti/
# 686   http://jberghold.github.io/2016-04-12-UTS/
# 695   http://intersectaustralia.github.io/2016-04-18-USYD/
# 698   https://bio-swc-bne.github.io/2016-04-19-GriffithUni/
# 718   http://combine-australia.github.io/2016-05-12-CharlesDarwinUni/
# 743   https://bio-swc-bne.github.io/2016-05-31-CQU-R/index.html
# 752   https://bio-swc-bne.github.io/2016-06-06-GriffithUni-Python/
# 771   http://combine-australia.github.io/2016-06-16-VetSciUnimelb/
# 776   https://intersectaustralia.github.io/2016-06-21-LTU/
# 791   https://intersectaustralia.github.io/2016-07-11-UNSW/
# 794   https://bio-swc-bne.github.io/2016-07-11-bne-R/
# 798   http://curtinic.github.io/SWC-2016-07-18/
# 799   https://fgacenga.github.io/2016-07-18-usq/
# 801   https://alistairwalsh.github.io/2016-07-20-UTS_Library_Data_Carpentry/
# 809   https://bio-swc-bne.github.io/2016-08-02-dsiti
# 813   https://datasciencehobart.github.io/2016-08-05-hobart/
# 817   https://alistairwalsh.github.io/2016-08-10-Pre-Pycon_Data_Carpentry_Workshop/
# 821   https://intersectaustralia.github.io/2016-08-16-WSU/
# 854   https://bio-swc-bne.github.io/2016-09-14-GriffithUni-Python/
# 864   https://intersectaustralia.github.io/2016-09-21-UON/
# 868   https://fgacenga.github.io/2016-09-26-usq/
# 869   https://jcu-eresearch.github.io/2016-09-27-SoftwareCarpentry-tsv/
# 870   https://intersectaustralia.github.io/2016-09-27-UNSW/
# 872   https://bio-swc-bne.github.io/2016-09-28-GriffithUni-R/
# 882   https://intersectaustralia.github.io/2016-10-05-LTU/
# 886   https://bio-swc-bne.github.io/2016-10-06-QBI/
# 907   https://philippbayer.github.io/2016-10-25-uwa/
# 924   https://curtinic.github.io/SWC-2016-11-07-Curtin/
# 934   https://nicjhan.github.io/2016-11-14-unimelb/
# 944   https://bio-swc-bne.github.io/2016-11-29-qut/
# 954   http://intersectaustralia.github.io/2016-12-12-Deakin
# 986   https://martinheroux.github.io/2017-01-30-NeuRA-Python/
# 987   https://datasciencehobart.github.io/2017-01-31-resbaztas-python/
# 988   https://datasciencehobart.github.io/2017-01-31-resbaztas-r/
# 996   https://damienirving.github.io/2017-02-05-amos/
# 1015  http://daryavanichkina.com/2017-02-27-UTS/
# 1017  https://jcu-eresearch.github.io/2017-03-02-SoftwareCarpentry-tsv/
# 1030  https://jcu-eresearch.github.io/2017-03-16-SoftwareCarpentryPy-TSV/
# 1047  https://jcu-eresearch.github.io/2017-04-06-DataCarpentry-Genomics-TSV
# 1052  https://bio-swc-bne.github.io/2017-04-10-GriffithUni-Python/
# 1055  https://bio-swc-bne.github.io/2017-04-12-GriffithUni-Git
# 1056  https://combine-australia.github.io/2017-04-20-SWC-Melbourne/
# 1086  https://lizcw.github.io/2017-05-17-qbi/
# 1088  https://martinheroux.github.io/2017-05-18-R-Macquarie/
# 1102  https://bio-swc-bne.github.io/2017-05-29-GriffithUni-R/
# 1107  https://curtinic.github.io/SWC-2017-06-06-Curtin/
# 1117  https://benmarwick.github.io/2017-06-15-uow/
# 1139  https://intersectaustralia.github.io/2017-07-03-ResBaz-Python/
# 1140  https://intersectaustralia.github.io/2017-07-03-ResBaz-R/
# 1143  https://jduckles.github.io/2017-07-03-sydney-resbaz-r-novice/
# 1148  https://bio-swc-bne.github.io/2017-07-10-uqws/
# 1167  https://datatas.github.io/2017-07-27-hobart/
# 1175  https://bio-swc-bne.github.io/2017-08-01-resbazp/
# 1176  https://bio-swc-bne.github.io/2017-08-01-resbazr/
# 1189  https://lizcw.github.io/2017-08-10-qbi/
# 1205  https://bio-swc-bne.github.io/2017-08-21-GriffithUni-R/
# 1210  https://curtinic.github.io/SWC-CIC/
# 1214  https://denubis.github.io/2017-08-31-MacquarieUniversity/
# 1237  https://fgacenga.github.io/2017-09-25-usq/index.html
# 1239  https://denubis.github.io/2017-09-26-MacquarieUniversity/
# 1290  https://weaverbel.github.io/2017-10-31-qut/
# 1302  https://curtinic.github.io/2017-11-07-curtin/
# 1317  https://bio-swc-bne.github.io/2017-11-23-GriffithUni-Python/
# 1318  https://joannadiong.github.io/2017-11-27-USyd-Python/
# 1333  https://adivea.github.io/2017-12-12-MQU-R/
# 1375  https://resbaz.github.io/resbaz2018/perth/
# 1387  https://damienirving.github.io/2018-02-04-amos-icshmo/
# 1390  https://bio-swc-bne.github.io/2018-02-07-GriffithUni-Python/
# 1400  https://adivea.github.io/2018-02-20-MQU-DC/
# 1401  https://stapleto.github.io/2018-02-20-qut/
# 1447  https://curtinic.github.io/2018-03-19-curtin/
# 1475  https://bio-swc-bne.github.io/2018-04-11-GriffithUni-R/
# 1489  https://curtinic.github.io/2018-04-23-curtin/
# 1499  https://combine-australia.github.io/2018-4-26-SWC-Melbourne/
# 1517  https://mq-software-carpentry.github.io/2018-05-10-macquarie-university/
# 1546  https://bio-swc-bne.github.io/2018-06-06-ResbazBris-Python/
# 1547  https://bio-swc-bne.github.io/2018-06-06-ResbazBris-R/
# 1560  https://weaverbel.github.io/2018-06-12-wrds/
# 1591  https://bio-swc-bne.github.io/2018-06-28-uqws/
# 1594  https://piccolomud.github.io/2018-07-03-ResBazPythonIntro/
# 1595  http://daryavanichkina.com/2018-07-03-ResbazSydney/
# 1597  https://mq-software-carpentry.github.io/2018-07-03-resbaz-python-advanced/
# 1598  https://humburg.github.io/2018-07-03-resbaz-sydneyAdvR/
# 1599  https://denubis.github.io/2018-07-03-resbaz2018sql/
# 1609  https://curtinic.github.io/2018-07-16-curtin/
# 1657  https://stapleto.github.io/swc-2018-08-28-qut/
# 1687  https://mq-software-carpentry.github.io/2018-09-18-mq-python/
# 1711  https://fgacenga.github.io/2018-10-02-usq/
# 1718  https://bio-swc-bne.github.io/2018-10-08-GriffithUni-Python/
# 1757  https://denubis.github.io/2018-10-29-MacquarieUniversity/
# 1868  http://vlsci.github.io/datacarpentry_2015-11-23_VLSCI/
#
#         country country3 workshop_type
# 53    Australia  AUS      SWC
# 54    Australia  AUS      SWC
# 117   Australia  AUS      SWC
# 121   Australia  AUS      SWC
# 123   Australia  AUS      SWC
# 132   Australia  AUS      SWC
# 153   Australia  AUS      SWC
# 155   Australia  AUS      SWC
# 158   Australia  AUS      SWC
# 168   Australia  AUS      SWC
# 196   Australia  AUS      SWC
# 228   Australia  AUS      SWC
# 234   Australia  AUS      SWC
# 246   Australia  AUS      SWC
# 264   Australia  AUS      SWC
# 280   Australia  AUS      SWC
# 318   Australia  AUS      SWC
# 319   Australia  AUS      SWC
# 320   Australia  AUS      SWC
# 347   Australia  AUS      SWC
# 367   Australia  AUS      SWC
# 368   Australia  AUS      SWC
# 377   Australia  AUS      SWC
# 392   Australia  AUS      SWC
# 420   Australia  AUS      SWC
# 422   Australia  AUS      SWC
# 423   Australia  AUS      SWC
# 427   Australia  AUS      SWC
# 429   Australia  AUS      SWC
# 434   Australia  AUS      SWC
# 445   Australia  AUS      SWC
# 474   Australia  AUS      SWC
# 480   Australia  AUS      SWC
# 494   Australia  AUS      SWC
# 497   Australia  AUS      SWC
# 498   Australia  AUS      SWC
# 499   Australia  AUS      SWC
# 505   Australia  AUS      DC
# 510   Australia  AUS      SWC
# 531   Australia  AUS      SWC
# 553   Australia  AUS      SWC
# 557   Australia  AUS      SWC
# 560   Australia  AUS      SWC
# 562   Australia  AUS      SWC
# 568   Australia  AUS      SWC
# 569   Australia  AUS      SWC
# 573   Australia  AUS      SWC
# 617   Australia  AUS      SWC
# 618   Australia  AUS      SWC
# 619   Australia  AUS      SWC
# 620   Australia  AUS      SWC
# 622   Australia  AUS      SWC
# 623   Australia  AUS      SWC
# 624   Australia  AUS      SWC
# 675   Australia  AUS      SWC
# 676   Australia  AUS      SWC
# 682   Australia  AUS      SWC
# 684   Australia  AUS      SWC
# 686   Australia  AUS      SWC
# 695   Australia  AUS      SWC
# 698   Australia  AUS      SWC
# 718   Australia  AUS      DC
# 743   Australia  AUS      SWC
# 752   Australia  AUS      SWC
# 771   Australia  AUS      SWC
# 776   Australia  AUS      SWC
# 791   Australia  AUS      SWC
# 794   Australia  AUS      SWC
# 798   Australia  AUS      SWC
# 799   Australia  AUS      SWC
# 801   Australia  AUS      DC
# 809   Australia  AUS      SWC
# 813   Australia  AUS      SWC
# 817   Australia  AUS      DC
# 821   Australia  AUS      SWC
# 854   Australia  AUS      SWC
# 864   Australia  AUS      SWC
# 868   Australia  AUS      SWC
# 869   Australia  AUS      SWC
# 870   Australia  AUS      SWC
# 872   Australia  AUS      SWC
# 882   Australia  AUS      SWC
# 886   Australia  AUS      SWC
# 907   Australia  AUS      DC
# 924   Australia  AUS      SWC
# 934   Australia  AUS      SWC
# 944   Australia  AUS      SWC
# 954   Australia  AUS      SWC
# 986   Australia  AUS      SWC
# 987   Australia  AUS      SWC
# 988   Australia  AUS      SWC
# 996   Australia  AUS      SWC
# 1015  Australia  AUS      SWC
# 1017  Australia  AUS      SWC
# 1030  Australia  AUS      SWC
# 1047  Australia  AUS      DC
# 1052  Australia  AUS      SWC
# 1055  Australia  AUS      SWC
# 1056  Australia  AUS      SWC
# 1086  Australia  AUS      SWC
# 1088  Australia  AUS      SWC
# 1102  Australia  AUS      SWC
# 1107  Australia  AUS      SWC
# 1117  Australia  AUS      DC
# 1139  Australia  AUS      SWC
# 1140  Australia  AUS      SWC
# 1143  Australia  AUS      SWC
# 1148  Australia  AUS      SWC
# 1167  Australia  AUS      SWC
# 1175  Australia  AUS      SWC
# 1176  Australia  AUS      SWC
# 1189  Australia  AUS      SWC
# 1205  Australia  AUS      SWC
# 1210  Australia  AUS      SWC
# 1214  Australia  AUS      SWC
# 1237  Australia  AUS      SWC
# 1239  Australia  AUS      SWC
# 1290  Australia  AUS      SWC
# 1302  Australia  AUS      SWC
# 1317  Australia  AUS      SWC
# 1318  Australia  AUS      SWC
# 1333  Australia  AUS      SWC
# 1375  Australia  AUS      SWC
# 1387  Australia  AUS      DC
# 1390  Australia  AUS      SWC
# 1400  Australia  AUS      DC
# 1401  Australia  AUS      SWC
# 1447  Australia  AUS      SWC
# 1475  Australia  AUS      SWC
# 1489  Australia  AUS      SWC
# 1499  Australia  AUS      SWC
# 1517  Australia  AUS      SWC
# 1546  Australia  AUS      SWC
# 1547  Australia  AUS      SWC
# 1560  Australia  AUS      SWC
# 1591  Australia  AUS      SWC
# 1594  Australia  AUS      SWC
# 1595  Australia  AUS      DC
# 1597  Australia  AUS      SWC
# 1598  Australia  AUS      SWC
# 1599  Australia  AUS      SWC
# 1609  Australia  AUS      SWC
# 1657  Australia  AUS      SWC
# 1687  Australia  AUS      SWC
# 1711  Australia  AUS      SWC
# 1718  Australia  AUS      SWC
# 1757  Australia  AUS      SWC
# 1868  Australia  AUS      DC
