# %%
## Import all the things

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import pycountry
import matplotlib.ticker as ticker
import datetime
# from scipy.stats import gaussian_kde
# from IPython.display import display, Markdown, Latex, display_markdown
from shapely.geometry import Point
# import folium
# from folium.plugins import HeatMap, HeatMapWithTime, MarkerCluster
# import os

# See plots in the notebook
# %matplotlib inline 

# This allows cells with long text values to wrap
pd.set_option('display.max_colwidth', -1)

pd.set_option('max_rows', 200)

# %%
# Load data for maps

# bounding box
bbox = gpd.read_file("../../data_files/spatial-vector-lidar/global/ne_110m_graticules_all/ne_110m_wgs84_bounding_box.shp")
bbox_robinson = bbox.to_crs('+proj=robin')


# world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')).to_crs(epsg=4326) #.to_crs('+proj=robin') # world map
world_robinson = world.to_crs('+proj=robin')


# Define constants - this will change with each report publication
report_date = pd.Timestamp(2018, 9, 30)

# %%
# Functions to clean up data

def get_country_name(alpha2_code):
    
    '''
    Takes a two character country code and
    returns the full name of the country.
    '''

    try:
        return pycountry.countries.get(alpha_2=alpha2_code).name
#         return pycountry.countries.
    except KeyError:
        if alpha2_code == "W3":
            return "online"
        else:
            return "unknown"
        
        
def get_country_code3(alpha2_code):
    
    '''
    Takes a two character country code and
    returns the full name of the country.
    '''

    try:
        return pycountry.countries.get(alpha_2=alpha2_code).alpha_3
#         return pycountry.countries.
    except KeyError:
        if alpha2_code == "W3":
            return "online"
        else:
            return "unknown"
        
        
# Function to create dataframes of counts and percentages by category (previous experience, expertise)
# when option is check many 
def get_value_counts_many(df, col_name, value_list):
    """
    Takes the parameters:
    * dataframe
    * the column in the df you want to group and count by
    * The list of characteristics (to ensure sort order)

    Returns a two column dataframe that has the grouped column and the count by that column

    
    """    
    
    df_counts = pd.DataFrame(columns=[col_name, 'Count'])
    
    for v in value_list:
#         count = df[col_name].apply(lambda x:x.count(v)).sum()
        count = df[col_name].str.count(v).sum()
        df_counts.loc[len(df_counts)] = [v, count]
        
    return df_counts

# %%
all_events = pd.read_csv("../../data_files/all_workshops.csv", keep_default_na=False, na_values=[''])



# Uncomment one of the following two blocks

# # Choose a 2 character country code from:  US, CA, GB, NZ, AU
chosen_country = "CA"
region_name = get_country_name(chosen_country)
all_events = all_events[all_events['country'] == chosen_country ]


# OR 

# Run for all African countries we've been in
# africa = ['ET', 'ZA', 'BW', 'GA', 'GH', 'KE', 'NA', 'SD', 'TZ', 'ZW',]
# region_name = "Africa"
# all_events = all_events[all_events.country.isin(africa)].copy()

# %% [markdown]
# # Carpentries workshops in  {{ region_name }}
#
# Data for 2018 is a projection.

# %%
# Load csv into df, filter just that country's workshops

#To select rows whose column value is in list 
# years = [1952, 2007]
# gapminder.year.isin(years)



# all_events = all_events[all_events['country'] == chosen_country ]
# # all_events = all_events[all_events.country.isin(africa)].copy()


# display(all_events)


####
# Replace country codes with full country name
# Set distinct workshop type (SWC, DC, LC, TTT)
# Set NaN attendance data to zero
# Convert workshop dates to date format
# Get just the regular workshops (not TTT events, not onboarding events, etc)
##### 

all_events.rename(columns={"country": "country2",}, inplace=True)



# Apply the function to get the full country name
all_events['country'] = all_events['country2'].apply(get_country_name)
all_events['country3'] = all_events['country2'].apply(get_country_code3)


# display(all_events)

# Clean up the tag names
# Create a new column for "workshop_type"; populate it SWC, DC, LC, or TTT
# Remove the old "tag_name" column
all_events.loc[all_events['tag_name'].str.contains("SWC"), "workshop_type"] = "SWC"
all_events.loc[all_events['tag_name'].str.contains("DC"), "workshop_type"] = "DC"
all_events.loc[all_events['tag_name'].str.contains("LC"), "workshop_type"] = "LC"
all_events.loc[all_events['tag_name'].str.contains("TTT"), "workshop_type"] = "TTT"
all_events = all_events.drop('tag_name', axis=1)

# Clean up attendance value - this is inconsistently stored as NaN or 0
# All zero values should be NaN
all_events['attendance'] =  all_events['attendance'].replace(0.0, np.nan)

# Date data type
all_events['start_date'] = pd.to_datetime(all_events['start_date'])


report_date = pd.Timestamp(2018, 10, 31)

# Remove events before report date
all_events = all_events[all_events['start_date'] < report_date]

# Remove instructor training events; these will be analyzed separately.
# Limit to non TTT workshops
workshops = all_events[all_events['workshop_type'] != "TTT"]

# Remove online events like maintainer onboarding
workshops = workshops.drop(workshops[workshops.country == "online"].index)

display(workshops)
# Out:
#                                  slug start_date  attendance  \
# 2     2012-02-23-toronto              2012-02-23  28.0
# 11    2012-05-16-alberta              2012-05-16  38.0
# 12    2012-05-22-ubc                  2012-05-22  39.0
# 17    2012-07-12-waterloo             2012-07-12  40.0
# 18    2012-07-16-halifax              2012-07-16  40.0
# 19    2012-07-19-utsc                 2012-07-19  39.0
# 27    2012-10-18-ubc                  2012-10-18  62.0
# 33    2012-11-08-mcmaster             2012-11-08  31.0
# 41    2013-01-11-ubc                  2013-01-11  18.0
# 43    2013-01-12-mcgill               2013-01-12  40.0
# 44    2013-01-12-waterloo             2013-01-12  24.0
# 45    2013-01-21-ubc                  2013-01-21  24.0
# 47    2013-01-24-camh                 2013-01-24  28.0
# 51    2013-02-05-ubc                  2013-02-05  30.0
# 76    2013-05-09-mozilla              2013-05-09  28.0
# 85    2013-05-30-alberta              2013-05-30  37.0
# 89    2013-06-06-sfu                  2013-06-06  37.0
# 115   2013-09-21-uwaterloo            2013-09-21  44.0
# 118   2013-09-26-ubc                  2013-09-26  24.0
# 137   2014-01-06-unb                  2014-01-06  20.0
# 145   2014-01-20-montreal             2014-01-20  26.0
# 154   2014-02-11-toronto              2014-02-11  23.0
# 160   2014-02-22-SFU                  2014-02-22  47.0
# 169   2014-04-02-uvic                 2014-04-02  26.0
# 174   2014-04-14-pycon                2014-04-14  40.0
# 175   2014-04-14-pycon-lib            2014-04-14  41.0
# 176   2014-04-14-pycon-ngs            2014-04-14  39.0
# 177   2014-04-14-pycon-r              2014-04-14  40.0
# 184   2014-05-05-mcmaster             2014-05-05  30.0
# 189   2014-05-12-oicr-toronto         2014-05-12  15.0
# 190   2014-05-12-ubc                  2014-05-12  16.0
# 208   2014-06-16-toronto              2014-06-16  38.0
# 210   2014-06-22-caims                2014-06-22  6.0
# 216   2014-07-02-smu                  2014-07-02  39.0
# 218   2014-07-08-wise-toronto         2014-07-08  44.0
# 221   2014-07-14-Dalhousie            2014-07-14  34.0
# 245   2014-09-13-uwaterloo            2014-09-13  25.0
# 252   2014-09-25-ubc                  2014-09-25  24.0
# 258   2014-10-06-rotman               2014-10-06  71.0
# 263   2014-10-30-utoronto             2014-10-30  24.0
# 269   2014-11-06-fmv                  2014-11-06  21.0
# 294   2015-01-08-uoit                 2015-01-08  24.0
# 295   2015-01-10-mcgill               2015-01-10  42.0
# 307   2015-01-27-ubc                  2015-01-27  31.0
# 309   2015-01-29-sickkids             2015-01-29  37.0
# 314   2015-02-05-toronto              2015-02-05  28.0
# 331   2015-03-05-ubc                  2015-03-05  40.0
# 339   2015-03-21-uwaterloo            2015-03-21  34.0
# 364   2015-04-30-SFU                  2015-04-30  57.0
# 372   2015-05-11-westernu             2015-05-11  40.0
# 419   2015-06-25-wise-toronto         2015-06-25  18.0
# 433   2015-07-16-sickkids             2015-07-16  38.0
# 440   2015-07-24-LSIUBC               2015-07-24  40.0
# 464   2015-08-27-ualberta             2015-08-27  37.0
# 483   2015-09-19-uwaterloo            2015-09-19  75.0
# 486   2015-09-22-ubc                  2015-09-22  11.0
# 493   2015-09-26-conestoga            2015-09-26  75.0
# 503   2015-10-05-ucalgary             2015-10-05  37.0
# 511   2015-10-17-SFU                  2015-10-17  30.0
# 513   2015-10-19-SWC-Acadia           2015-10-19  7.0
# 516   2015-10-19-ualberta             2015-10-19  26.0
# 522   2015-10-26-umanitoba            2015-10-26  13.0
# 523   2015-10-27-SWC-Universite-Laval 2015-10-27  40.0
# 536   2015-11-09-SWC-UQAM             2015-11-09  33.0
# 548   2015-11-19-utoronto             2015-11-19  38.0
# 587   2016-01-09-uwo                  2016-01-09  31.0
# 597   2016-01-16-ubc                  2016-01-16 NaN
# 598   2016-01-16-waterloo             2016-01-16  28.0
# 614   2016-01-29-UBC                  2015-01-29 NaN
# 625   2016-02-02-SFU                  2016-02-02 NaN
# 632   2016-02-06-uguelph              2016-02-06  27.0
# 637   2016-02-16-ualberta             2016-02-16  14.0
# 639   2016-02-17-queens               2016-02-17 NaN
# 641   2016-02-18-ucalgary             2016-02-18  10.0
# 646   2016-02-22-ubco                 2016-02-22 NaN
# 651   2016-03-01-Universite-Laval     2016-03-01  19.0
# 661   2016-03-12-ubc                  2016-03-12 NaN
# 668   2016-03-19-brocku               2016-03-19  18.0
# 679   2016-04-02-conestoga            2016-04-02  48.0
# 703   2016-04-25-utoronto             2016-04-25  29.0
# 706   2016-04-28-ualberta             2016-04-28  16.0
# 712   2016-05-05-saintmarys           2016-05-05 NaN
# 713   2016-05-05-uwaterloo            2016-05-05 NaN
# 716   2016-05-09-utoronto             2016-05-09  37.0
# 719   2016-05-14-ubc                  2016-05-14 NaN
# 724   2016-05-17-UBC                  2016-05-17 NaN
# 727   2016-05-21-ubc                  2016-05-21 NaN
# 732   2016-05-24-mcmaster             2016-05-24  32.0
# 740   2016-05-26-utoronto             2016-05-26  30.0
# 746   2016-06-01-mcgill               2016-06-01 NaN
# 751   2016-06-06-Bishops              2016-06-06 NaN
# 779   2016-06-23-CC                   2016-06-23 NaN
# 782   2016-06-23-ualberta-DC          2016-06-23  15.0
# 815   2016-08-08-uottawa              2016-08-08  30.0
# 851   2016-09-08-mcgill               2016-09-08  16.0
# 853   2016-09-13-Universite-Laval     2016-09-13  4.0
# 855   2016-09-14-mpac                 2016-09-14 NaN
# 856   2016-09-14-yorku                2016-09-14  28.0
# 858   2016-09-17-uwaterloo            2016-09-17  25.0
# 863   2016-09-20-ubc                  2016-09-20  19.0
# 876   2016-09-29-ubc                  2016-09-29  35.0
# 878   2016-10-03-sfu                  2016-10-03  19.0
# 883   2016-10-05-SFU                  2016-10-05  26.0
# 903   2016-10-22-uwo                  2016-10-22  25.0
# 905   2016-10-24-umontreal            2016-10-24 NaN
# 909   2016-10-26-queensu              2016-10-26  30.0
# 951   2016-12-07-uvic                 2016-12-07 NaN
# 985   2017-01-26-utoronto             2017-01-26  16.0
# 990   2017-02-02-SFU                  2017-02-02  32.0
# 993   2017-02-03-utoronto             2017-02-03  29.0
# 995   2017-02-04-conestoga            2017-02-04  40.0
# 1010  2017-02-21-queensu              2017-02-21  30.0
# 1012  2017-02-23-uottawa              2017-02-23  30.0
# 1019  2017-03-02-mcgill               2017-03-02  21.0
# 1023  2017-03-07-Universite-Laval     2017-03-07  20.0
# 1026  2017-03-11-ubc                  2017-03-11  44.0
# 1040  2017-03-25-brocku               2017-03-25  16.0
# 1060  2017-04-24-queensu              2017-04-24  30.0
# 1083  2017-05-15-ualberta             2017-05-15  25.0
# 1087  2017-05-18-McMaster             2017-05-18  27.0
# 1101  2017-05-27-MUN                  2017-05-27  22.0
# 1151  2017-07-12-ualberta-DC          2017-07-12  13.0
# 1168  2017-07-27-mcmaster             2017-07-27  30.0
# 1225  2017-09-18-SFU-python           2017-09-18 NaN
# 1241  2017-09-26-ubc                  2017-09-26  9.0
# 1247  2017-09-30-TDWG-Ottawa          2017-09-30  18.0
# 1261  2017-10-16-YorkU                2017-10-18 NaN
# 1279  2017-10-26-york-university      2017-10-26  20.0
# 1291  2017-10-31-ulaval               2017-10-31  21.0
# 1301  2017-11-06-umontreal            2017-11-06  19.0
# 1303  2017-11-07-mcgill               2017-11-07  17.0
# 1313  2017-11-15-ualberta             2017-11-15  10.0
# 1322  2017-11-30-queensu              2017-11-30  25.0
# 1326  2017-12-02-mun                  2017-12-02  33.0
# 1334  2017-12-12-acadia               2017-12-12  23.0
# 1339  2017-12-14-mcmaster             2017-12-14  27.0
# 1370  2018-01-18-utoronto             2018-01-18 NaN
# 1419  2018-03-03-conestoga            2018-03-03 NaN
# 1435  2018-03-12-mun                  2018-03-12  15.0
# 1441  2018-03-14-SFU-python           2018-03-14 NaN
# 1500  2018-04-30-sfu                  2018-04-30 NaN
# 1506  2018-05-03-queensu              2018-05-03 NaN
# 1514  2018-05-09-ualberta-dc          2018-05-09  24.0
# 1519  2018-05-14-ualberta-sc          2018-05-14  19.0
# 1531  2018-05-22-camh                 2018-05-22 NaN
# 1535  2018-05-26-conestoga            2018-05-26 NaN
# 1537  2018-05-28-ualberta-hpc         2018-05-28 NaN
# 1550  2018-06-07-mcmaster             2018-06-07 NaN
# 1571  2018-06-18-utoronto             2018-06-18  28.0
# 1607  2018-07-12-utoronto             2018-07-12 NaN
# 1676  2018-09-10-utoronto             2018-09-10  22.0
# 1700  2018-09-25-ualberta-HPC         2018-09-25  16.0
#
#                                                 host_name country2   latitude  \
# 2     University of Toronto                                CA       43.661476
# 11    University of Alberta                                CA       53.523454
# 12    University of British Columbia                       CA       49.261715
# 17    University of Waterloo                               CA       43.470130
# 18    Saint Mary's University                              CA       44.632261
# 19    University of Toronto (Scarborough)                  CA       43.783551
# 27    University of British Columbia                       CA       49.261715
# 33    McMaster University                                  CA       43.261328
# 41    University of British Columbia                       CA       49.261715
# 43    McGill University                                    CA       45.417417
# 44    University of Waterloo                               CA       43.469128
# 45    University of British Columbia                       CA       49.260605
# 47    Centre for Addiction and Mental Health               CA       43.647118
# 51    University of British Columbia                       CA       49.261715
# 76    Mozilla Foundation                                   CA       43.647120
# 85    University of Alberta                                CA       53.523450
# 89    Simon Fraser University                              CA       49.276765
# 115   University of Waterloo                               CA       43.468889
# 118   University of British Columbia                       CA       49.261111
# 137   University of New Brunswick                          CA       45.947214
# 145   Computer Research Institute of Montreal              CA       45.530677
# 154   Mozilla Foundation                                   CA       43.647110
# 160   Simon Fraser University                              CA       49.276765
# 169   University of Victoria                               CA       48.461821
# 174   PyCon                                                CA       45.530677
# 175   PyCon                                                CA       45.530677
# 176   PyCon                                                CA       45.530677
# 177   PyCon                                                CA       45.530677
# 184   McMaster University                                  CA       43.262739
# 189   Mozilla Foundation                                   CA       43.647110
# 190   University of British Columbia                       CA       49.265080
# 208   Mozilla Foundation                                   CA       43.647110
# 210   Canadian Applied and Industrial Mathematics Society  CA       52.127165
# 216   Saint Mary's University                              CA       44.631627
# 218   University of Toronto                                CA       43.659641
# 221   Dalhousie University                                 CA       44.637275
# 245   University of Waterloo                               CA       43.473269
# 252   University of British Columbia                       CA       49.263000
# 258   University of Toronto                                CA       43.665263
# 263   University of Toronto                                CA       43.662152
# 269   Universite de Montreal                               CA       45.619605
# 294   University of Ontario Institute of Technology        CA       43.945879
# 295   McGill University                                    CA       45.507380
# 307   University of British Columbia                       CA       49.260000
# 309   Hospital for Sick Children, Toronto                  CA       43.650000
# 314   University of Toronto                                CA       43.664928
# 331   University of British Columbia                       CA       49.264000
# 339   University of Waterloo                               CA       43.473269
# 364   Simon Fraser University                              CA       49.280019
# 372   Western University                                   CA       43.009747
# 419   University of Toronto                                CA       43.660889
# 433   Hospital for Sick Children, Toronto                  CA       43.656947
# 440   University of British Columbia                       CA       49.262360
# 464   University of Alberta                                CA       43.677718
# 483   University of Waterloo                               CA       43.473269
# 486   University of British Columbia                       CA       49.263000
# 493   Conestoga College                                    CA       43.389485
# 503   University of Calgary                                CA       51.078677
# 511   Simon Fraser University                              CA       49.278094
# 513   Acadia University                                    CA       45.091100
# 516   University of Alberta                                CA       53.525607
# 522   University of Manitoba                               CA       49.808501
# 523   University of Laval                                  CA       46.778826
# 536   Université du Québec à Montréal                      CA       45.508655
# 548   University of Toronto                                CA       43.661824
# 587   Western University                                   CA       43.009790
# 597   University of British Columbia                       CA       49.262465
# 598   University of Waterloo                               CA       43.473226
# 614   University of British Columbia                       CA       49.264142
# 625   Simon Fraser University                              CA       49.279660
# 632   University of Guelph                                 CA       43.531468
# 637   University of Alberta                                CA       53.522084
# 639   Queen's University                                   CA       44.227793
# 641   University of Calgary                                CA       51.077752
# 646   University of British Columbia                       CA       49.939120
# 651   University of Laval                                  CA       46.778826
# 661   University of British Columbia                       CA       49.262465
# 668   Brock University                                     CA       43.159374
# 679   Conestoga College                                    CA       43.389485
# 703   University of Toronto                                CA       43.664550
# 706   University of Alberta                                CA       53.527609
# 712   Saint Mary's University                              CA       44.632284
# 713   University of Waterloo                               CA       43.467900
# 716   University of Toronto                                CA       43.664550
# 719   University of British Columbia                       CA       49.262465
# 724   University of British Columbia                       CA       49.266697
# 727   University of British Columbia                       CA       49.262465
# 732   McMaster University                                  CA       43.262245
# 740   University of Toronto                                CA       43.664550
# 746   McGill University                                    CA       45.508983
# 751   Université Bishop's                                  CA       45.365938
# 779   Compute Canada                                       CA       53.527033
# 782   University of Alberta                                CA       53.527297
# 815   Compute Canada                                       CA       45.422661
# 851   McGill University                                    CA       45.507401
# 853   University of Laval                                  CA       46.778826
# 855   Municipal Property Assessment Corporation            CA       43.838012
# 856   York University                                      CA       43.771350
# 858   University of Waterloo                               CA       43.473269
# 863   University of British Columbia                       CA       49.262737
# 876   University of British Columbia                       CA       49.262465
# 878   Simon Fraser University                              CA       49.279549
# 883   Simon Fraser University                              CA       49.279618
# 903   Western University                                   CA       43.009834
# 905   Universite de Montreal                               CA       45.499093
# 909   Queen's University                                   CA       44.226744
# 951   University of Victoria                               CA       48.463898
# 985   University of Toronto                                CA       43.664550
# 990   Simon Fraser University                              CA       49.284542
# 993   University of Toronto                                CA       43.664550
# 995   Conestoga College                                    CA       43.389485
# 1010  Queen's University                                   CA       44.227517
# 1012  Univerity of Ottawa                                  CA       45.422072
# 1019  McGill University                                    CA       45.507373
# 1023  University of Laval                                  CA       46.778608
# 1026  University of British Columbia                       CA       49.262465
# 1040  Brock University                                     CA       43.159374
# 1060  Queen's University                                   CA       44.227517
# 1083  University of Alberta                                CA       53.527609
# 1087  McMaster University                                  CA       43.259659
# 1101  Memorial University                                  CA       47.573124
# 1151  University of Alberta                                CA       53.526942
# 1168  McMaster University                                  CA       43.259659
# 1225  Simon Fraser University                              CA       49.279591
# 1241  University of British Columbia                       CA       49.262465
# 1247  University of Florida                                CA       45.412766
# 1261  York University                                      CA       43.774742
# 1279  York University                                      CA       43.773227
# 1291  University of Laval                                  CA      NaN
# 1301  Universite de Montreal                               CA       45.504804
# 1303  McGill University                                    CA       45.504666
# 1313  University of Alberta                                CA       53.526003
# 1322  Queen's University                                   CA       44.227362
# 1326  Memorial University                                  CA       47.571306
# 1334  Acadia University                                    CA       45.088573
# 1339  McMaster University                                  CA       43.261027
# 1370  University of Toronto                                CA       43.662195
# 1419  Conestoga College                                    CA       43.389485
# 1435  Memorial University                                  CA       47.571693
# 1441  Simon Fraser University                              CA       49.279591
# 1500  Simon Fraser University                              CA       49.277537
# 1506  Queen's University                                   CA       44.227565
# 1514  University of Alberta                                CA       53.526591
# 1519  University of Alberta                                CA       53.521575
# 1531  Centre for Addiction and Mental Health               CA       43.659501
# 1535  Conestoga College                                    CA       43.389485
# 1537  University of Alberta                                CA       53.521575
# 1550  McMaster University                                  CA       43.260879
# 1571  University of Toronto                                CA       43.662195
# 1607  University of Toronto                                CA       43.662195
# 1676  University of Toronto                                CA       43.662195
# 1700  University of Alberta                                CA       53.528117
#
#        longitude  \
# 2    -79.395189
# 11   -113.525995
# 12   -123.253430
# 17   -80.535771
# 18   -63.580263
# 19   -79.186397
# 27   -123.253430
# 33   -79.920248
# 41   -123.253430
# 43   -73.948928
# 44   -80.539865
# 45   -123.245994
# 47   -79.394300
# 51   -123.253430
# 76   -79.394300
# 85   -113.526000
# 89   -122.917957
# 115  -80.540000
# 118  -123.253056
# 137  -66.640325
# 145  -73.624497
# 154  -79.394230
# 160  -122.917957
# 169  -123.310443
# 174  -73.624497
# 175  -73.624497
# 176  -73.624497
# 177  -73.624497
# 184  -79.917598
# 189  -79.394230
# 190  -123.253780
# 208  -79.394230
# 210  -106.658892
# 216  -63.580168
# 218  -79.396792
# 221  -63.588926
# 245  -80.538639
# 252  -123.252000
# 258  -79.398620
# 263  -79.394085
# 269  -72.963607
# 294  -78.896292
# 295  -73.579080
# 307  -123.250000
# 309  -79.380000
# 314  -79.399387
# 331  -123.250000
# 339  -80.538639
# 364  -122.922205
# 372  -81.272473
# 419  -79.398807
# 433  -79.388435
# 440  -123.244940
# 464  -79.432773
# 483  -80.538639
# 486  -123.252000
# 493  -80.404178
# 503  -114.133959
# 511  -122.919883
# 513  -64.361400
# 516  -113.521621
# 522  -97.133615
# 523  -71.275169
# 536  -73.570663
# 548  -79.394539
# 587  -81.272822
# 597  -123.245090
# 598  -80.538639
# 614  -123.249592
# 625  -122.918856
# 632  -80.227913
# 637  -113.526331
# 639  -76.499333
# 641  -114.130029
# 646  -119.394442
# 651  -71.275169
# 661  -123.245090
# 668  -79.246863
# 679  -80.404178
# 703  -79.399462
# 706  -113.522002
# 712  -63.580241
# 713  -80.543200
# 716  -79.399462
# 719  -123.245090
# 724  -123.254331
# 727  -123.245090
# 732  -79.920286
# 740  -79.399462
# 746  -73.581343
# 751  -71.849049
# 779  -113.521746
# 782  -113.519881
# 815  -75.682470
# 851  -73.579024
# 853  -71.275169
# 855  -79.075581
# 856  -79.500785
# 858  -80.538639
# 863  -123.252236
# 876  -123.245090
# 878  -122.918354
# 883  -122.920939
# 903  -81.272660
# 905  -73.617969
# 909  -76.496898
# 951  -123.309689
# 985  -79.399462
# 990  -123.111646
# 993  -79.399462
# 995  -80.404178
# 1010 -76.495229
# 1012 -75.682669
# 1019 -73.579064
# 1023 -71.274771
# 1026 -123.245090
# 1040 -79.246863
# 1060 -76.495229
# 1083 -113.522002
# 1087 -79.917486
# 1101 -52.733152
# 1151 -113.529550
# 1168 -79.917486
# 1225 -122.918721
# 1241 -123.245090
# 1247 -75.688662
# 1261 -79.504922
# 1279 -79.498257
# 1291 NaN
# 1301 -73.613556
# 1303 -73.573502
# 1313 -113.529153
# 1322 -76.497260
# 1326 -52.732711
# 1334 -64.366817
# 1339 -79.916996
# 1370 -79.393965
# 1419 -80.404178
# 1435 -52.733248
# 1441 -122.918721
# 1500 -122.914015
# 1506 -76.497241
# 1514 -113.524765
# 1519 -113.526347
# 1531 -79.389670
# 1535 -80.404178
# 1537 -113.526347
# 1550 -79.919225
# 1571 -79.393965
# 1607 -79.393965
# 1676 -79.393965
# 1700 -113.525747
#
#                                                                   url country  \
# 2     https://swcarpentry.github.io/2012-02-23-toronto/                Canada
# 11    https://swcarpentry.github.io/2012-05-16-alberta/                Canada
# 12    https://swcarpentry.github.io/2012-05-22-ubc/                    Canada
# 17    https://swcarpentry.github.io/2012-07-12-waterloo/               Canada
# 18    https://swcarpentry.github.io/2012-07-16-halifax/                Canada
# 19    https://swcarpentry.github.io/2012-07-19-utsc/                   Canada
# 27    https://swcarpentry.github.io/2012-10-18-ubc/                    Canada
# 33    https://swcarpentry.github.io/2012-11-08-mcmaster/               Canada
# 41    https://swcarpentry.github.io/2013-01-11-ubc/                    Canada
# 43    https://swcarpentry.github.io/2013-01-12-mcgill/                 Canada
# 44    https://swcarpentry.github.io/2013-01-12-waterloo/               Canada
# 45    http://cannot.find.url/2013-01-21-ubc/                           Canada
# 47    https://swcarpentry.github.io/2013-01-24-camh/                   Canada
# 51    https://swcarpentry.github.io/2013-02-05-ubc/                    Canada
# 76    https://swcarpentry.github.io/2013-05-09-mozilla/                Canada
# 85    https://swcarpentry.github.io/2013-05-30-alberta/                Canada
# 89    https://swcarpentry.github.io/2013-06-06-sfu/                    Canada
# 115   https://swcarpentry.github.io/2013-09-21-uwaterloo/              Canada
# 118   https://swcarpentry.github.io/2013-09-26-ubc/                    Canada
# 137   https://jooolia.github.io/2014-01-06-unb/                        Canada
# 145   https://gvwilson.github.io/2014-01-20-montreal/                  Canada
# 154   https://swcarpentry.github.io/2014-02-11-toronto/                Canada
# 160   https://bernhardkonrad.github.io/2014-02-22-SFU/                 Canada
# 169   https://swcarpentry.github.io/2014-04-02-uvic/                   Canada
# 174   https://swcarpentry.github.io/2014-04-14-pycon/                  Canada
# 175   https://dhavide.github.io/2014-04-14-pycon-lib/                  Canada
# 176   https://swcarpentry.github.io/2014-04-14-pycon-ngs/              Canada
# 177   https://swcarpentry.github.io/2014-04-14-pycon-r/                Canada
# 184   https://gdevenyi.github.io/2014-05-05-mcmaster/                  Canada
# 189   https://swcarpentry.github.io/2014-05-12-oicr-toronto/           Canada
# 190   https://jennybc.github.io/2014-05-12-ubc/                        Canada
# 208   https://swcarpentry.github.io/2014-06-16-toronto/                Canada
# 210   https://dhavide.github.io/2014-06-22-caims/                      Canada
# 216   https://dhavide.github.io/2014-07-02-smu/                        Canada
# 218   https://erdavenport.github.io/2014-07-08-wise-toronto/           Canada
# 221   https://dbarneche.github.io/2014-07-14-Dalhousie/                Canada
# 245   https://amjoconn.github.io/2014-09-13-uwaterloo/                 Canada
# 252   https://douglatornell.github.io/2014-09-25-ubc/                  Canada
# 258   https://swcarpentry.github.io/2014-10-06-rotman/                 Canada
# 263   https://swcarpentry.github.io/2014-10-30-utoronto/               Canada
# 269   https://dhaine.github.io/2014-11-06-fmv/                         Canada
# 294   https://dhavide.github.io/2015-01-08-uoit/                       Canada
# 295   https://igor-kozlov.github.io/2015-01-10-mcgill/                 Canada
# 307   https://billmills.github.io/2015-01-27-ubc/                      Canada
# 309   https://tomwright01.github.io/2015-01-29-sickkids/               Canada
# 314   https://swcarpentry.github.io/2015-02-05-toronto/                Canada
# 331   https://nsoontie.github.io/2015-03-05-ubc/                       Canada
# 339   https://amjoconn.github.io/2015-03-21-uwaterloo/                 Canada
# 364   https://ttimbers.github.io/2015-04-30-SFU/                       Canada
# 372   https://pbarmby.github.io/2015-05-11-westernu/                   Canada
# 419   https://swcarpentry.github.io/2015-06-25-wise-toronto/           Canada
# 433   https://tomwright01.github.io/2015-07-16-sickkids/               Canada
# 440   https://billmills.github.io/2015-07-24-LSIUBC/                   Canada
# 464   https://cmacdonell.github.io/2015-08-27-ualberta/                Canada
# 483   https://ppomorsk.github.io/2015-09-19-uwaterloo/                 Canada
# 486   https://douglatornell.github.io/2015-09-22-ubc/                  Canada
# 493   https://ppomorsk.github.io/2015-09-26-conestoga/                 Canada
# 503   https://ttimbers.github.io/2015-10-05-UC/                        Canada
# 511   https://ttimbers.github.io/2015-10-17-SFU/                       Canada
# 513   https://remi-daigle.github.io/2015-10-19-SWC-Acadia/             Canada
# 516   https://ComputeCanada.github.io/2015-10-19-ualberta/             Canada
# 522   https://computecanada.github.io/2015-10-26-umanitoba/            Canada
# 523   https://calculquebec.github.io/2015-10-27-SWC-Universite-Laval/  Canada
# 536   https://computecanada.github.io/2015-11-09-SWC-UQAM/             Canada
# 548    http://blog.tomwright.ca/2015-11-19-utoronto/                   Canada
# 587   http://computecanada.github.io/2016-01-09-uwo/                   Canada
# 597   http://computecanada.github.io/2016-01-16-ubc                    Canada
# 598   http://ikajic.github.io/2016-01-16-waterloo/                     Canada
# 614   https://lmguzman.github.io/2016-01-29-UBC/                       Canada
# 625   http://bgran.de/2016-02-02-SFU/                                  Canada
# 632   https://computecanada.github.io/2016-02-06-uguelph/              Canada
# 637   http://computecanada.github.io/2016-02-16-ualberta/              Canada
# 639   http://haschmi.github.io/2016-02-17-queens/                      Canada
# 641   http://computecanada.github.io/2016-02-18-ucalgary/              Canada
# 646   http://computecanada.github.io/2016-02-22-ubco                   Canada
# 651   http://computecanada.github.io/2016-03-01-Universite-Laval/      Canada
# 661   http://computecanada.github.io/2016-03-12-ubc                    Canada
# 668   http://computecanada.github.io/2016-03-19-brocku/                Canada
# 679   http://ppomorsk.github.io/2016-04-02-conestoga/                  Canada
# 703   http://uoftcoders.github.io/2016-04-25-utoronto/                 Canada
# 706   http://computecanada.github.io/2016-04-28-ualberta/              Canada
# 712   http://computecanada.github.io/2016-05-05-saintmarys/            Canada
# 713   http://ppomorsk.github.io/2016-05-05-uwaterloo/                  Canada
# 716   http://uoftcoders.github.io/2016-05-09-utoronto/                 Canada
# 719   http://computecanada.github.io/2016-05-14-ubc                    Canada
# 724   http://billmills.github.io/2016-05-17-UBC/                       Canada
# 727   http://computecanada.github.io/2016-05-21-ubc                    Canada
# 732   http://computecanada.github.io/2016-05-24-mcmaster/              Canada
# 740   http://uoftcoders.github.io/2016-05-26-utoronto/                 Canada
# 746   http://mkcor.github.io/2016-06-01-mcgill/                        Canada
# 751   https://ecole2016.calculquebec.ca/                               Canada
# 779   http://datacarpentry.github.io/2016-06-23-CC/                    Canada
# 782   http://www.datacarpentry.org/2016-06-23-CC/                      Canada
# 815   https://cac-staff.github.io/summer-school-2016                   Canada
# 851   https://computecanada.github.io/2016-09-08-mcgill/               Canada
# 853   https://computecanada.github.io/2016-09-13-Universite-Laval      Canada
# 855   https://rahmanisahar.github.io/2016-Sep-14-MPAC/                 Canada
# 856   https://gvwilson.github.io/2016-09-14-yorku/                     Canada
# 858   https://ppomorsk.github.io/2016-09-17-uwaterloo/                 Canada
# 863   https://douglatornell.github.io/2016-09-20-ubc/                  Canada
# 876   https://computecanada.github.io/2016-09-29-ubc                   Canada
# 878   https://computecanada.github.io/2016-10-03-sfu                   Canada
# 883   http://bgran.de/2016-10-05-SFU/                                  Canada
# 903   https://jnandez.github.io/2016-10-22-uwo/                        Canada
# 905   http://poisotlab.io/2016-10-24-umontreal/                        Canada
# 909   https://cac-staff.github.io/swc-queens-2016-oct/                 Canada
# 951   https://jpwrobinson.github.io/2016-12-07                         Canada
# 985   https://ppomorsk.github.io/2017-01-26-utoronto/                  Canada
# 990   http://bgran.de/2017-02-02-SFU/                                  Canada
# 993   https://uoftcoders.github.io/2017-02-03-utoronto/                Canada
# 995   https://ppomorsk.github.io/2017-02-04-conestoga/                 Canada
# 1010  https://cac-staff.github.io/swc-queens-2017-feb/                 Canada
# 1012  https://cac-staff.github.io/swc-uottawa-2017-feb/                Canada
# 1019  https://computecanada.github.io/2017-03-02-mcgill/               Canada
# 1023  https://computecanada.github.io/2017-03-07-Universite-Laval/     Canada
# 1026  https://computecanada.github.io/2017-03-11-ubc/                  Canada
# 1040  https://computecanada.github.io/2017-03-25-brocku/               Canada
# 1060  https://cac-staff.github.io/swc-queens-2017-apr/                 Canada
# 1083  https://computecanada.github.io/2017-05-15-ualberta/             Canada
# 1087  https://jcszamosi.github.io/2017-05-18-McMaster/                 Canada
# 1101  https://rmdickson.github.io/2017-05-27-MUN/                      Canada
# 1151  https://computecanada.github.io/2017-07-12-ualberta-DC/          Canada
# 1168  https://jcszamosi.github.io/2017-07-27-McMaster/                 Canada
# 1225  https://gallingerj.github.io/2017-09-18-SFU-python/              Canada
# 1241  https://computecanada.github.io/2017-09-26-ubc/                  Canada
# 1247  https://idigbio.github.io/2017-09-30-TDWG-Ottawa/                Canada
# 1261  https://remi-daigle.github.io/2017-10-16-YorkU/                  Canada
# 1279  https://sechilds.github.io/2017-10-26-york-university/           Canada
# 1291  NaN                                                              Canada
# 1301  https://computecanada.github.io/2017-11-06-umontreal/            Canada
# 1303  https://computecanada.github.io/2017-11-07-mcgill/               Canada
# 1313  https://computecanada.github.io/2017-11-15-ualberta/             Canada
# 1322  https://cac-staff.github.io/2017-11-30-queensu/                  Canada
# 1326  https://daniellequinn.github.io/2017-12-02-mun/                  Canada
# 1334  https://daniellequinn.github.io/2017-12-12-acadia/               Canada
# 1339  https://jcszamosi.github.io/2017-12-14-McMaster/                 Canada
# 1370  https://uoftcoders.github.io/2018-01-18-utoronto/                Canada
# 1419  https://ppomorsk.github.io/2018-03-03-conestoga/                 Canada
# 1435  https://mun-swc-hub.github.io/2018-03-12-mun/                    Canada
# 1441  https://gallingerj.github.io/2018-03-14-SFU-python/              Canada
# 1500  https://computecanada.github.io/2018-04-30-sfu                   Canada
# 1506  https://cac-staff.github.io/2018-05-03-queensu/                  Canada
# 1514  https://computecanada.github.io/2018-05-09-ualberta-dc/          Canada
# 1519  https://computecanada.github.io/2018-05-14-ualberta-sc/          Canada
# 1531  https://canghel.github.io/2018-05-22-camh/                       Canada
# 1535  https://ppomorsk.github.io/2018-05-26-conestoga/                 Canada
# 1537  https://computecanada.github.io/2018-05-28-ualberta-hpc/         Canada
# 1550  https://jcszamosi.github.io/2018-06-07-McMaster/                 Canada
# 1571  https://uoftcoders.github.io/2018-06-18-utoronto/                Canada
# 1607  https://uoftcoders.github.io/2018-07-12-utoronto/                Canada
# 1676  https://uoftcoders.github.io/2018-09-10-utoronto                 Canada
# 1700  https://computecanada.github.io/2018-09-25-ualberta-HPC/         Canada
#
#      country3 workshop_type
# 2     CAN      SWC
# 11    CAN      SWC
# 12    CAN      SWC
# 17    CAN      SWC
# 18    CAN      SWC
# 19    CAN      SWC
# 27    CAN      SWC
# 33    CAN      SWC
# 41    CAN      SWC
# 43    CAN      SWC
# 44    CAN      SWC
# 45    CAN      SWC
# 47    CAN      SWC
# 51    CAN      SWC
# 76    CAN      SWC
# 85    CAN      SWC
# 89    CAN      SWC
# 115   CAN      SWC
# 118   CAN      SWC
# 137   CAN      SWC
# 145   CAN      SWC
# 154   CAN      SWC
# 160   CAN      SWC
# 169   CAN      SWC
# 174   CAN      SWC
# 175   CAN      SWC
# 176   CAN      SWC
# 177   CAN      SWC
# 184   CAN      SWC
# 189   CAN      SWC
# 190   CAN      SWC
# 208   CAN      SWC
# 210   CAN      SWC
# 216   CAN      SWC
# 218   CAN      SWC
# 221   CAN      SWC
# 245   CAN      SWC
# 252   CAN      SWC
# 258   CAN      SWC
# 263   CAN      SWC
# 269   CAN      SWC
# 294   CAN      SWC
# 295   CAN      SWC
# 307   CAN      SWC
# 309   CAN      SWC
# 314   CAN      SWC
# 331   CAN      SWC
# 339   CAN      SWC
# 364   CAN      SWC
# 372   CAN      SWC
# 419   CAN      SWC
# 433   CAN      SWC
# 440   CAN      SWC
# 464   CAN      SWC
# 483   CAN      SWC
# 486   CAN      SWC
# 493   CAN      SWC
# 503   CAN      SWC
# 511   CAN      SWC
# 513   CAN      SWC
# 516   CAN      SWC
# 522   CAN      SWC
# 523   CAN      SWC
# 536   CAN      SWC
# 548   CAN      SWC
# 587   CAN      SWC
# 597   CAN      SWC
# 598   CAN      SWC
# 614   CAN      SWC
# 625   CAN      SWC
# 632   CAN      SWC
# 637   CAN      SWC
# 639   CAN      SWC
# 641   CAN      SWC
# 646   CAN      SWC
# 651   CAN      SWC
# 661   CAN      SWC
# 668   CAN      SWC
# 679   CAN      SWC
# 703   CAN      SWC
# 706   CAN      SWC
# 712   CAN      SWC
# 713   CAN      SWC
# 716   CAN      SWC
# 719   CAN      SWC
# 724   CAN      SWC
# 727   CAN      SWC
# 732   CAN      SWC
# 740   CAN      SWC
# 746   CAN      SWC
# 751   CAN      SWC
# 779   CAN      DC
# 782   CAN      DC
# 815   CAN      SWC
# 851   CAN      SWC
# 853   CAN      SWC
# 855   CAN      SWC
# 856   CAN      SWC
# 858   CAN      SWC
# 863   CAN      SWC
# 876   CAN      SWC
# 878   CAN      SWC
# 883   CAN      SWC
# 903   CAN      DC
# 905   CAN      SWC
# 909   CAN      SWC
# 951   CAN      SWC
# 985   CAN      SWC
# 990   CAN      SWC
# 993   CAN      SWC
# 995   CAN      SWC
# 1010  CAN      SWC
# 1012  CAN      SWC
# 1019  CAN      SWC
# 1023  CAN      SWC
# 1026  CAN      SWC
# 1040  CAN      SWC
# 1060  CAN      SWC
# 1083  CAN      SWC
# 1087  CAN      SWC
# 1101  CAN      SWC
# 1151  CAN      DC
# 1168  CAN      SWC
# 1225  CAN      SWC
# 1241  CAN      SWC
# 1247  CAN      DC
# 1261  CAN      SWC
# 1279  CAN      SWC
# 1291  CAN      SWC
# 1301  CAN      SWC
# 1303  CAN      SWC
# 1313  CAN      DC
# 1322  CAN      SWC
# 1326  CAN      SWC
# 1334  CAN      SWC
# 1339  CAN      DC
# 1370  CAN      SWC
# 1419  CAN      SWC
# 1435  CAN      SWC
# 1441  CAN      SWC
# 1500  CAN      SWC
# 1506  CAN      SWC
# 1514  CAN      DC
# 1519  CAN      SWC
# 1531  CAN      DC
# 1535  CAN      SWC
# 1537  CAN      SWC
# 1550  CAN      SWC
# 1571  CAN      DC
# 1607  CAN      DC
# 1676  CAN      DC
# 1700  CAN      SWC

# %%
# Count of workshops by Carpentry and by year. This year's data is actual, not projected.

workshops_by_carpentry_year = workshops.groupby([workshops['start_date'].dt.year, 'workshop_type'])['slug'].count().unstack()

# To calculate projections for current year, take number of workshops at same point in last year

# Get the year of the max date in our data set
current_year = max(workshops['start_date'].dt.year)

# Get one year ago based on that
last_year = current_year - 1

# Get the actual date of the latest workshop in our data set
latest_workshop_date = max(workshops['start_date'])

# Get the comparison date one year ago
last_year_comparision_date = max(workshops['start_date']) - datetime.timedelta(days=365)

# January 1 of last year
# last_year_first_day = datetime.date(last_year, 1, 1)
last_year_first_day = pd.Timestamp(last_year, 1, 1)

# Count how many workshops happened between Jan 1 of last year and the comparison date one year ago
last_year_workshops_to_comp_date = workshops[(workshops.start_date >= last_year_first_day) & (workshops.start_date <= last_year_comparision_date)]

# Count how many workshops happened total last year
count_last_year_workshops = len(workshops[workshops['start_date'].dt.year == last_year])

# Count YTD workshops this year
count_this_year_workshops = len(workshops[workshops['start_date'].dt.year == current_year])

# Last year's workshops by Carpentry by year through the comparison date
last_year_to_comp_date_by_carpentry = last_year_workshops_to_comp_date.groupby([last_year_workshops_to_comp_date['start_date'].dt.year, 'workshop_type'])['slug'].count().unstack()

# Last year's workshops by Carpentry by year total
last_year_total_by_carpentry = workshops_by_carpentry_year.loc[[last_year]]

# This year's workshops by Carpentry by year to date
this_year_to_date_by_carpentry = workshops_by_carpentry_year.loc[[current_year]]

# Proportion of workshops by Carpentry by year that had occured by the comparison date
proportion = last_year_to_comp_date_by_carpentry/last_year_total_by_carpentry

# Rename the rows so we can run calculations on them
this_year_to_date_by_carpentry.rename({current_year:1}, inplace=True)
proportion.rename({last_year:1}, inplace=True)

# Assuming current year will progress at same proportionate rate
# calculate the projected number of workshops for the current year
current_year_projected = this_year_to_date_by_carpentry.iloc[[0]]/proportion.iloc[[0]]

# Rename the row for the current year projections
current_year_projected.rename({1:current_year}, inplace=True)

# In the workshops by carpentry year dataframe, replace the actual current year data
# with projected current year data
workshops_by_carpentry_year.loc[[current_year]] = current_year_projected.loc[[current_year]]

# Replace the NaNs with 0 and convert floats to ints
workshops_by_carpentry_year.fillna(0, inplace=True)
workshops_by_carpentry_year = workshops_by_carpentry_year.round(0)
workshops_by_carpentry_year = workshops_by_carpentry_year.astype(int)


workshops_by_carpentry_year.index.name = 'Year'
workshops_by_carpentry_year.columns.name = "Workshop Type"

current_year_workshops = dict((workshops_by_carpentry_year.loc[current_year]))

# %% [markdown]
# ### {{ region_name }}  Based Workshops by Carpentry by year
# Data for 2018 is a projection.

# %%
fig = plt.figure(figsize=(12, 6)) # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes

width = .5 # Set width of bar
title = "Carpentries workshops count by year in " + region_name

# Set axes labels and legend
ax.set_xlabel("Year")
ax.set_ylabel("Workshop Count")
# ax.legend(title="Workshop Type", fontsize=12)

ax.title.set_size(18)
ax.xaxis.label.set_size(18)
ax.yaxis.label.set_size(18)
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize=14, rotation=0)

# Plot chart
workshops_by_carpentry_year.plot(y = ["DC", "SWC"], kind='bar', ax=ax, width=width,  title=title, stacked=True,)

leg = ax.legend(fontsize=12)
leg.set_title(title="Workshop Type", prop={'size':14,})


# Customize the gridlines
ax.grid(linestyle='-', linewidth='0.25', color='gray')

# Create a new dataframe that has just the total number of workshops by year
totals = workshops_by_carpentry_year['DC'] + workshops_by_carpentry_year['SWC']
years = list(totals.index)


# Figure out what the xmarks values are (xtick values; they are not year like you'd think)
# Add them to an empty list
# The list will be double what's expected as it goes through all the stacked values
xmarks = []
for p in ax.patches:
#     print("X: ", p.get_x())
#     print("Y: ", p.get_height())
    xmarks.append(p.get_x())


# Make an empty list to be populated with a tuple for each stack
# Go through the length of the totals series
# Add to the empty list a tuple: (position in totals df, position in xmarks list)
t = []

for y in range(len(totals)):
    t.append((list(totals)[y], xmarks[y]))


# Annotate the stacked bar chart with 
# (annotation text, position of text)
for p in t:
    ax.annotate(str(p[0]), (p[1] + .08, p[0] + 5), fontsize=14)

# Don't allow the axis to be on top of your data
ax.set_axisbelow(True)    

ax.set_ylim(0,max(totals) + 50)

    
# Display the plot   
plt.show()


# See
# https://stackoverflow.com/questions/40783669/stacked-bar-plot-by-group-count-on-pandas-python

# %%
workshops_with_location = workshops[workshops.latitude.notnull()]
workshops_with_location = workshops_with_location[workshops_with_location.longitude.notnull()]

# For more info see 
# https://www.earthdatascience.org/courses/earth-analytics-python/spatial-data-vector-shapefiles/intro-to-coordinate-reference-systems-python/
# https://github.com/geopandas/geopandas/issues/245

# Make simple df with just the latlon columns
latlon = workshops_with_location[['longitude', 'latitude']]

# world map with latlong projections
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')).to_crs(epsg=4326) #.to_crs('+proj=robin') # world map

# Turn latlon into list of shapely points
q  = [Point(xy) for xy in latlon.values]

# Create geodataframe using these points
q = gpd.GeoDataFrame(q, columns = ['geometry'])

# q.head()
# This is a "naive" object; need to explicitly set the crs to 4326 (latlon)
q.crs = {'init': 'epsg:4326', 'no_defs': True}

# Now translate both latlons to robinson projection - a bit "rounder"
# world = world.to_crs('+proj=robin')
q = q.to_crs('+proj=robin')


fig, ax = plt.subplots(figsize=(15, 8))

# Not sure what alpha means
bbox_robinson.plot(ax=ax, alpha=1, color='whitesmoke', edgecolor='dimgray')


world_robinson.plot(color='darkgrey', ax=ax,)

q.plot(ax=ax, color='royalblue', marker='o', markersize=10)

# ax.axis('off')

# facecolor will not work if ax.axis is off
# ax.patch.set_facecolor('whitesmoke')
# # Drop x & y axis ticks
plt.xticks([], [])
plt.yticks([], [])

ax.set_title("Carpentries workshops, 2012-2018 in " + region_name )
ax.title.set_size(18)



# Make the axes invisible by making them the same color as the background
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white') 
ax.spines['right'].set_color('white')
ax.spines['left'].set_color('white')



plt.show()

# %%
workshops_current_year = workshops[workshops['start_date'].dt.year == current_year].copy()
workshops_current_year.attendance.fillna(0, inplace=True)
current_year_no_attendance = workshops_current_year[workshops_current_year.attendance ==0].copy()
percent_missing_attendance =  len(current_year_no_attendance)/len(workshops_current_year) * 100
percent_missing_attendance = int(percent_missing_attendance)

if percent_missing_attendance > 0:
    text = "In " + str(current_year) + ", " + str(percent_missing_attendance) + "% of workshops in " + region_name + \
    " do not have attendance recorded.  Below are all workshops missing attendance."
else:
    text = "All workshops in " + region_name + " have complete attendance records."


# percent_missing_attendance

# %% [markdown]
# ## Learners and Attendance in {{ region_name }}
#
# {{ text }}

# %%
if percent_missing_attendance > 0:
    display(current_year_no_attendance)
# Out:
#                          slug start_date  attendance  \
# 1370  2018-01-18-utoronto     2018-01-18  0.0
# 1419  2018-03-03-conestoga    2018-03-03  0.0
# 1441  2018-03-14-SFU-python   2018-03-14  0.0
# 1500  2018-04-30-sfu          2018-04-30  0.0
# 1506  2018-05-03-queensu      2018-05-03  0.0
# 1531  2018-05-22-camh         2018-05-22  0.0
# 1535  2018-05-26-conestoga    2018-05-26  0.0
# 1537  2018-05-28-ualberta-hpc 2018-05-28  0.0
# 1550  2018-06-07-mcmaster     2018-06-07  0.0
# 1607  2018-07-12-utoronto     2018-07-12  0.0
#
#                                    host_name country2   latitude   longitude  \
# 1370  University of Toronto                   CA       43.662195 -79.393965
# 1419  Conestoga College                       CA       43.389485 -80.404178
# 1441  Simon Fraser University                 CA       49.279591 -122.918721
# 1500  Simon Fraser University                 CA       49.277537 -122.914015
# 1506  Queen's University                      CA       44.227565 -76.497241
# 1531  Centre for Addiction and Mental Health  CA       43.659501 -79.389670
# 1535  Conestoga College                       CA       43.389485 -80.404178
# 1537  University of Alberta                   CA       53.521575 -113.526347
# 1550  McMaster University                     CA       43.260879 -79.919225
# 1607  University of Toronto                   CA       43.662195 -79.393965
#
#                                                            url country  \
# 1370  https://uoftcoders.github.io/2018-01-18-utoronto/         Canada
# 1419  https://ppomorsk.github.io/2018-03-03-conestoga/          Canada
# 1441  https://gallingerj.github.io/2018-03-14-SFU-python/       Canada
# 1500  https://computecanada.github.io/2018-04-30-sfu            Canada
# 1506  https://cac-staff.github.io/2018-05-03-queensu/           Canada
# 1531  https://canghel.github.io/2018-05-22-camh/                Canada
# 1535  https://ppomorsk.github.io/2018-05-26-conestoga/          Canada
# 1537  https://computecanada.github.io/2018-05-28-ualberta-hpc/  Canada
# 1550  https://jcszamosi.github.io/2018-06-07-McMaster/          Canada
# 1607  https://uoftcoders.github.io/2018-07-12-utoronto/         Canada
#
#      country3 workshop_type
# 1370  CAN      SWC
# 1419  CAN      SWC
# 1441  CAN      SWC
# 1500  CAN      SWC
# 1506  CAN      SWC
# 1531  CAN      DC
# 1535  CAN      SWC
# 1537  CAN      SWC
# 1550  CAN      SWC
# 1607  CAN      DC

# %%
# Learners by year


# Actual data for learners by year through 2018
# Projections for 2018 are calculated below

learners_by_year = workshops.groupby([workshops['start_date'].dt.year, 'workshop_type'])['attendance'].sum().unstack()
learners_by_year = learners_by_year.fillna(0)
# learners_by_year.rename(columns={'slug': 'learner_count'}, inplace=True)
# # workshops_by_country_year['total'] = workshops_by_country_year.sum(axis=1)
# learners_by_year.columns.names = ['Year']
# # workshops_by_country_year[current_year] = workshops_by_country_year[current_year]/.75
learners_by_year = learners_by_year.astype(int)

# # display(workshops_by_country_year)

# ##############

# Last year's attendance by year through the comparison date
# # Take *all* of last year's workshop by the com date and group them by Carpentry type
last_year_to_comp_date_attendance = last_year_workshops_to_comp_date.groupby([workshops['start_date'].dt.year, 'workshop_type'])['attendance'].sum().unstack()
# # # current_year_projected.rename({1:current_year}, inplace=True)
# last_year_to_comp_date_by_country.rename(columns={'slug':last_year}, inplace=True)

# Last year's workshops attendance by year total
# # Get just the last_year column from the workshops_by_country_year df
learners_last_year = learners_by_year.loc[[last_year]]

# Rename the rows so we can run calculations on them
learners_by_year.rename({current_year:1}, inplace=True)

x = last_year_to_comp_date_attendance/learners_last_year


x.rename({last_year:1}, inplace=True)

# learners_by_year.loc[[2018]]/x.loc[[2017]]
# display(x.loc[[2017]])
# display(learners_by_year.loc[[2018]])
# learners_by_year.loc[[2018]]/x.loc[[2017]]
learners_by_year.loc[[1]] = learners_by_year.loc[[1]]/x
learners_by_year.rename({1:current_year}, inplace=True)
learners_by_year = learners_by_year.round(0)
learners_by_year = learners_by_year.astype(int)


learners_by_year.index.name = 'Year'
learners_by_year.columns.name = "Workshop Type"

# %%
fig = plt.figure(figsize=(12, 6)) # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes

width = .5 # Set width of bar
title = "Carpentries attendance by year in " + region_name
 
# Plot chart
# Having position=1 as an argument will make the bars not be centered on the x ticks
learners_by_year.plot(y = ["DC", "SWC"], kind='bar', ax=ax, width=width, title=title, stacked=True,)

# Set axes labels and legend
ax.set_xlabel("Year")
ax.set_ylabel("Workshop Count")
# ax.legend(title="Workshop Type", fontsize=12)
leg = ax.legend(fontsize=12)
leg.set_title(title="Workshop Type", prop={'size':14,})
ax.title.set_size(18)
ax.xaxis.label.set_size(18)
ax.yaxis.label.set_size(18)
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize=14, rotation=0)



# Customize the gridlines
ax.grid(linestyle='-', linewidth='0.25', color='gray')

# Create a new dataframe that has just the total number of workshops by year
totals = learners_by_year['DC'] + learners_by_year['SWC']
years = list(totals.index)


# Figure out what the xmarks values are (xtick values; they are not year like you'd think)
# Add them to an empty list
# The list will be double what's expected as it goes through all the stacked values
xmarks = []
for p in ax.patches:
#     print("X: ", p.get_x())
#     print("Y: ", p.get_height())
    xmarks.append(p.get_x())


# Make an empty list to be populated with a tuple for each stack
# Go through the length of the totals series
# Add to the empty list a tuple: (position in totals df, position in xmarks list)
t = []

for y in range(len(totals)):
    t.append((list(totals)[y], xmarks[y]))


# Annotate the stacked bar chart with 
# (annotation text, position of text)
for p in t:
    ax.annotate(str(p[0]), (p[1] + .08, p[0] + 100), fontsize=14)

# Don't allow the axis to be on top of your data
ax.set_axisbelow(True)    

ax.set_ylim(0,max(totals) + 500)

    
# Display the plot   
plt.show()


# See
# https://stackoverflow.com/questions/40783669/stacked-bar-plot-by-group-count-on-pandas-python

# %% [markdown]
# ### All workshops by Carpentry by Year in {{ region_name }}

# %%
display(workshops_by_carpentry_year)
# Out:
# Workshop Type  DC  SWC
# Year
# 2012           0   8
# 2013           0   11
# 2014           0   22
# 2015           0   25
# 2016           3   38
# 2017           4   25
# 2018           20  17

# %% [markdown]
# ### Attendance by Carpentry by Year in {{ region_name }}

# %%
display(learners_by_year)
# Out:
# Workshop Type   DC  SWC
# Year
# 2012           0    317
# 2013           0    334
# 2014           0    689
# 2015           0    851
# 2016           40   571
# 2017           68   579
# 2018           387  70
